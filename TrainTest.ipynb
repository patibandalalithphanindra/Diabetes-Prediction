# %%
import pandas as pd

# %%
df = pd.read_csv('dataset.csv')
df
# Out:
#      Pregnancies   Glucose   Insulin       BMI       Age  Outcome
# 0       0.352941  0.670968  0.573168  0.393862  0.483333        1
# 1       0.058824  0.264516  0.573168  0.214834  0.166667        0
# 2       0.470588  0.896774  0.573168  0.130435  0.183333        1
# 3       0.058824  0.290323  0.309013  0.253197  0.000000        0
# 4       0.294118  0.464516  0.573168  0.189258  0.150000        0
# ..           ...       ...       ...       ...       ...      ...
# 694     0.588235  0.367742  0.678112  0.375959  0.700000        0
# 695     0.117647  0.503226  0.573168  0.475703  0.100000        0
# 696     0.294118  0.496774  0.386266  0.204604  0.150000        0
# 697     0.058824  0.529032  0.573168  0.304348  0.433333        1
# 698     0.058824  0.316129  0.573168  0.312020  0.033333        0
#
# [699 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split
x = df.iloc[:,:-1]
y = df.iloc[:,-1]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=5)

# %% [markdown]
# LR

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(random_state=0)
model.fit(x_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
predicted_y = model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, predicted_y)
print(cm)
# Out:
# [[115   8]
#  [ 20  32]]

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, predicted_y)
accuracy
# Out:
# 0.84

# %%
from sklearn.metrics import precision_score
precision_score(y_test, predicted_y)
# Out:
# 0.8

# %%
from sklearn.metrics import recall_score
recall_score(y_test, predicted_y)
# Out:
# 0.6153846153846154

# %%
from sklearn.metrics import f1_score
f1_score(y_test, predicted_y)
# Out:
# 0.6956521739130435

# %% [markdown]
# DT

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()
dtree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
predicted_y = dtree.predict(x_test)
accuracy = accuracy_score(y_test, predicted_y)

# %%
cm = confusion_matrix(y_test, predicted_y)
cm
# Out:
# array([[97, 26],
#        [20, 32]])

# %%
print(accuracy)
# Out:
# 0.7371428571428571

# %%
from sklearn.metrics import precision_recall_fscore_support
precision_recall_fscore_support(y_test, predicted_y)
# Out:
# (array([0.82905983, 0.55172414]),
#  array([0.78861789, 0.61538462]),
#  array([0.80833333, 0.58181818]),
#  array([123,  52]))

# %%
from sklearn.metrics import precision_score
precision_score(y_test, predicted_y)
# Out:
# 0.5517241379310345

# %% [markdown]
# RF

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(random_state=0)
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
predicted_y = model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, predicted_y)
print(cm)
# Out:
# [[105  18]
#  [ 12  40]]

# %%
accuracy = accuracy_score(y_test, predicted_y)
accuracy
# Out:
# 0.8285714285714286

# %%
from sklearn.metrics import precision_recall_fscore_support
precision_recall_fscore_support(y_test, predicted_y)
# Out:
# (array([0.8974359 , 0.68965517]),
#  array([0.85365854, 0.76923077]),
#  array([0.875     , 0.72727273]),
#  array([123,  52]))

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=7)
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
predicted_y = model.predict(x_test)

# %%
cm = confusion_matrix(y_test, predicted_y)
print(cm)
# Out:
# [[107  16]
#  [ 16  36]]

# %%
accuracy = accuracy_score(y_test, predicted_y)
accuracy
# Out:
# 0.8171428571428572

# %%
from sklearn.metrics import precision_recall_fscore_support
precision_recall_fscore_support(y_test, predicted_y)
# Out:
# (array([0.8699187 , 0.69230769]),
#  array([0.8699187 , 0.69230769]),
#  array([0.8699187 , 0.69230769]),
#  array([123,  52]))

# %% [markdown]
# SVM

# %%
from sklearn.svm import SVC
model = SVC()
model.fit(x_train, y_train)
# Out:
# SVC()

# %%
predicted_y = model.predict(x_test)

# %%
cm = confusion_matrix(y_test, predicted_y)
print(cm)
# Out:
# [[114   9]
#  [ 20  32]]

# %%
accuracy = accuracy_score(y_test, predicted_y)
accuracy
# Out:
# 0.8342857142857143

# %%
from sklearn.metrics import precision_recall_fscore_support
precision_recall_fscore_support(y_test, predicted_y)
# Out:
# (array([0.85074627, 0.7804878 ]),
#  array([0.92682927, 0.61538462]),
#  array([0.88715953, 0.68817204]),
#  array([123,  52]))

# %% [markdown]
# NB

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
predicted_y = model.predict(x_test)

# %%
cm = confusion_matrix(y_test, predicted_y)
print(cm)
# Out:
# [[102  21]
#  [ 17  35]]

# %%
accuracy = accuracy_score(y_test, predicted_y)
accuracy
# Out:
# 0.7828571428571428

# %%
from sklearn.metrics import precision_recall_fscore_support
precision_recall_fscore_support(y_test, predicted_y)
# Out:
# (array([0.85714286, 0.625     ]),
#  array([0.82926829, 0.67307692]),
#  array([0.84297521, 0.64814815]),
#  array([123,  52]))

# %% [markdown]
# Adaboost

# %%
from sklearn.ensemble import AdaBoostClassifier
model = AdaBoostClassifier()
model.fit(x_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
predicted_y = model.predict(x_test)

# %%
cm = confusion_matrix(y_test, predicted_y)
print(cm)
# Out:
# [[104  19]
#  [ 14  38]]

# %%
accuracy = accuracy_score(y_test, predicted_y)
accuracy
# Out:
# 0.8114285714285714

# %%
from sklearn.metrics import precision_recall_fscore_support
precision_recall_fscore_support(y_test, predicted_y)
# Out:
# (array([0.88135593, 0.66666667]),
#  array([0.84552846, 0.73076923]),
#  array([0.86307054, 0.69724771]),
#  array([123,  52]))
