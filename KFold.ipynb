# %%
import pandas as pd

# %%
df = pd.read_csv('sample_data/dataset.csv')
df
# Out:
#      Pregnancies   Glucose   Insulin       BMI       Age  Outcome
# 0       0.352941  0.670968  0.573168  0.393862  0.483333        1
# 1       0.058824  0.264516  0.573168  0.214834  0.166667        0
# 2       0.470588  0.896774  0.573168  0.130435  0.183333        1
# 3       0.058824  0.290323  0.309013  0.253197  0.000000        0
# 4       0.294118  0.464516  0.573168  0.189258  0.150000        0
# ..           ...       ...       ...       ...       ...      ...
# 694     0.588235  0.367742  0.678112  0.375959  0.700000        0
# 695     0.117647  0.503226  0.573168  0.475703  0.100000        0
# 696     0.294118  0.496774  0.386266  0.204604  0.150000        0
# 697     0.058824  0.529032  0.573168  0.304348  0.433333        1
# 698     0.058824  0.316129  0.573168  0.312020  0.033333        0
#
# [699 rows x 6 columns]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import AdaBoostClassifier

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %% [markdown]
# Decision Tree

# %%
import numpy as np
from sklearn.model_selection import KFold, cross_val_score
kfold = KFold(n_splits=10)
model = DecisionTreeClassifier()
cv = cross_val_score(model, x, y, cv=kfold, scoring='accuracy')
np.mean(cv)
# Out:
# 0.7381573498964803

# %%
cv = cross_val_score(model, x, y, cv=kfold, scoring='precision')
np.mean(cv)
# Out:
# 0.6198822653450603

# %%
cv = cross_val_score(model, x, y, cv=kfold, scoring='recall')
np.mean(cv)
# Out:
# 0.5993597465336596

# %%
cv = cross_val_score(model, x, y, cv=kfold, scoring='f1')
np.mean(cv)
# Out:
# 0.5891384455234562

# %% [markdown]
# Random Forest

# %%
model = RandomForestClassifier()
cv = cross_val_score(model, x, y, cv=kfold, scoring='accuracy')
np.mean(cv)
# Out:
# 0.7481987577639752

# %%
cv = cross_val_score(model, x, y, cv=kfold, scoring='precision')
np.mean(cv)
# Out:
# 0.6515132908675108

# %%
cv = cross_val_score(model, x, y, cv=kfold, scoring='recall')
np.mean(cv)
# Out:
# 0.6045995148169061

# %%
cv = cross_val_score(model, x, y, cv=kfold, scoring='f1')
np.mean(cv)
# Out:
# 0.6346445801942109

# %% [markdown]
# Gaussian NB

# %%
model = GaussianNB()
cv = cross_val_score(model, x, y, cv=kfold, scoring='accuracy')
np.mean(cv)
# Out:
# 0.7567908902691511

# %%
cv = cross_val_score(model, x, y, cv=kfold, scoring='precision')
np.mean(cv)
# Out:
# 0.6482797466812812

# %%
cv = cross_val_score(model, x, y, cv=kfold, scoring='recall')
np.mean(cv)
# Out:
# 0.6195494280276889

# %%
cv = cross_val_score(model, x, y, cv=kfold, scoring='f1')
np.mean(cv)
# Out:
# 0.6270061138713815

# %% [markdown]
# Logistic Regression

# %%
model = LogisticRegression()
cv = cross_val_score(model, x, y, cv=kfold, scoring='accuracy')
np.mean(cv)
# Out:
# 0.7768530020703934

# %%
cv = cross_val_score(model, x, y, cv=kfold, scoring='precision')
np.mean(cv)
# Out:
# 0.7400201106083459

# %%
cv = cross_val_score(model, x, y, cv=kfold, scoring='recall')
np.mean(cv)
# Out:
# 0.5214906832298136

# %%
cv = cross_val_score(model, x, y, cv=kfold, scoring='f1')
np.mean(cv)
# Out:
# 0.6074289253974411

# %% [markdown]
# Ada Boost

# %%
model = AdaBoostClassifier()
cv = cross_val_score(model, x, y, cv=kfold, scoring='accuracy')
np.mean(cv)
# Out:
# 0.7510559006211179

# %%
cv = cross_val_score(model, x, y, cv=kfold, scoring='precision')
np.mean(cv)
# Out:
# 0.6605322240538959

# %%
cv = cross_val_score(model, x, y, cv=kfold, scoring='recall')
np.mean(cv)
# Out:
# 0.5498828868394086

# %%
cv = cross_val_score(model, x, y, cv=kfold, scoring='f1')
np.mean(cv)
# Out:
# 0.5919240964903931

# %% [markdown]
# SVM

# %%
model = SVC()
cv = cross_val_score(model, x, y, cv=kfold, scoring='accuracy')
np.mean(cv)
# Out:
# 0.7625258799171843

# %%
cv = cross_val_score(model, x, y, cv=kfold, scoring='precision')
np.mean(cv)
# Out:
# 0.7058736821314221

# %%
cv = cross_val_score(model, x, y, cv=kfold, scoring='recall')
np.mean(cv)
# Out:
# 0.49893740719827673

# %%
cv = cross_val_score(model, x, y, cv=kfold, scoring='f1')
np.mean(cv)
# Out:
# 0.580187295624122

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=7)

# %%
cv = cross_val_score(model, x, y, cv=kfold, scoring='accuracy')
np.mean(cv)
# Out:
# 0.7710766045548654

# %%
cv = cross_val_score(model, x, y, cv=kfold, scoring='precision')
np.mean(cv)
# Out:
# 0.6755612242755185

# %%
cv = cross_val_score(model, x, y, cv=kfold, scoring='recall')
np.mean(cv)
# Out:
# 0.6325992847731979

# %%
cv = cross_val_score(model, x, y, cv=kfold, scoring='f1')
np.mean(cv)
# Out:
# 0.6458614900751656
