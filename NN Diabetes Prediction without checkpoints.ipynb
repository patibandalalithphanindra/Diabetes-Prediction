# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf

# %%
data = pd.read_csv('/content/dataset.csv')
# Out:
# 0    466
# 1    233
# Name: Outcome, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x = data.iloc[:,:-1]
y = data.iloc[:,-1]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=5)

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(5, input_shape=(5, )))
model.add(tf.keras.layers.Dense(5, activation="relu"))
model.add(tf.keras.layers.Dense(1, activation="sigmoid"))

model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_24 (Dense)            (None, 5)                 30
#
#  dense_25 (Dense)            (None, 5)                 30
#
#  dense_26 (Dense)            (None, 1)                 6
#
# =================================================================
# Total params: 66
# Trainable params: 66
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(5, input_shape=(5, )))
model.add(tf.keras.layers.Dense(26, activation="relu"))
model.add(tf.keras.layers.Dense(5, activation="relu"))
model.add(tf.keras.layers.Dense(1, activation="sigmoid"))

model_2.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_27 (Dense)            (None, 5)                 30
#
#  dense_28 (Dense)            (None, 26)                156
#
#  dense_29 (Dense)            (None, 5)                 135
#
#  dense_30 (Dense)            (None, 1)                 6
#
# =================================================================
# Total params: 327
# Trainable params: 327
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(5, input_shape=(5, )))
model.add(tf.keras.layers.Dense(16, activation="relu"))
model.add(tf.keras.layers.Dense(10, activation="relu"))
model.add(tf.keras.layers.Dense(5, activation="relu"))
model.add(tf.keras.layers.Dense(1, activation="sigmoid"))

model_3.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_31 (Dense)            (None, 5)                 30
#
#  dense_32 (Dense)            (None, 16)                96
#
#  dense_33 (Dense)            (None, 10)                170
#
#  dense_34 (Dense)            (None, 5)                 55
#
#  dense_35 (Dense)            (None, 1)                 6
#
# =================================================================
# Total params: 357
# Trainable params: 357
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import SGD

opt = SGD(lr=0.01, momentum=0.9)

model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(5, input_shape=(5, )))
model.add(tf.keras.layers.Dense(5, activation="relu"))
model.add(tf.keras.layers.Dense(1, activation="sigmoid"))
model.compile(optimizer=opt, metrics='accuracy', loss='mse')

model.fit(x_train, y_train, batch_size=15, epochs=200, verbose=0, validation_data=(x_test, y_test))
_, acc = model.evaluate(x_test, y_test)
print('1:200 '+str(acc))

model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(5, input_shape=(5, )))
model.add(tf.keras.layers.Dense(5, activation="relu"))
model.add(tf.keras.layers.Dense(1, activation="sigmoid"))
model.compile(optimizer=opt, metrics='accuracy', loss='mse')

model.fit(x_train, y_train, batch_size=15, epochs=400, verbose=0, validation_data=(x_test, y_test))
_, acc = model.evaluate(x_test, y_test)
print('1:400 '+str(acc))

model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(5, input_shape=(5, )))
model.add(tf.keras.layers.Dense(5, activation="relu"))
model.add(tf.keras.layers.Dense(1, activation="sigmoid"))
model.compile(optimizer=opt, metrics='accuracy', loss='mse')

model.fit(x_train, y_train, batch_size=15, epochs=800, verbose=0, validation_data=(x_test, y_test))
_, acc = model.evaluate(x_test, y_test)
print('1:800 '+str(acc))
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1301 - accuracy: 0.8229
# 1:200 0.822857141494751
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1335 - accuracy: 0.8114
# 1:400 0.8114285469055176
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1274 - accuracy: 0.8286
# 1:800 0.8285714387893677

# %%
from tensorflow.keras.optimizers import SGD

opt = SGD(lr=0.01, momentum=0.9)

model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(5, input_shape=(5, )))
model.add(tf.keras.layers.Dense(26, activation="relu"))
model.add(tf.keras.layers.Dense(5, activation="relu"))
model.add(tf.keras.layers.Dense(1, activation="sigmoid"))
model.compile(optimizer=opt, metrics='accuracy', loss='mse')

model.fit(x_train, y_train, batch_size=15, epochs=200, verbose=0, validation_data=(x_test, y_test))
_, acc = model.evaluate(x_test, y_test)
print('2:200 '+str(acc))

model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(5, input_shape=(5, )))
model.add(tf.keras.layers.Dense(26, activation="relu"))
model.add(tf.keras.layers.Dense(5, activation="relu"))
model.add(tf.keras.layers.Dense(1, activation="sigmoid"))
model.compile(optimizer=opt, metrics='accuracy', loss='mse')

model.fit(x_train, y_train, batch_size=15, epochs=400, verbose=0, validation_data=(x_test, y_test))
_, acc = model.evaluate(x_test, y_test)
print('2:400 '+str(acc))

model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(5, input_shape=(5, )))
model.add(tf.keras.layers.Dense(26, activation="relu"))
model.add(tf.keras.layers.Dense(5, activation="relu"))
model.add(tf.keras.layers.Dense(1, activation="sigmoid"))
model.compile(optimizer=opt, metrics='accuracy', loss='mse')

model.fit(x_train, y_train, batch_size=15, epochs=800, verbose=0, validation_data=(x_test, y_test))
_, acc = model.evaluate(x_test, y_test)
print('2:800 '+str(acc))
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1267 - accuracy: 0.8114
# 2:200 0.8114285469055176
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1254 - accuracy: 0.8171
# 2:400 0.8171428442001343
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1353 - accuracy: 0.8114
# 2:800 0.8114285469055176

# %%
from tensorflow.keras.optimizers import SGD

opt = SGD(lr=0.01, momentum=0.9)

model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(5, input_shape=(5, )))
model.add(tf.keras.layers.Dense(16, activation="relu"))
model.add(tf.keras.layers.Dense(10, activation="relu"))
model.add(tf.keras.layers.Dense(5, activation="relu"))
model.add(tf.keras.layers.Dense(1, activation="sigmoid"))
model.compile(optimizer=opt, metrics='accuracy', loss='mse')
model.fit(x_train, y_train, batch_size=15, epochs=200, verbose=0, validation_data=(x_test, y_test))
_, acc = model.evaluate(x_test, y_test)
print('3:200 '+str(acc))

model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(5, input_shape=(5, )))
model.add(tf.keras.layers.Dense(16, activation="relu"))
model.add(tf.keras.layers.Dense(10, activation="relu"))
model.add(tf.keras.layers.Dense(5, activation="relu"))
model.add(tf.keras.layers.Dense(1, activation="sigmoid"))
model.compile(optimizer=opt, metrics='accuracy', loss='mse')
model.fit(x_train, y_train, batch_size=15, epochs=400, verbose=0, validation_data=(x_test, y_test))
_, acc = model.evaluate(x_test, y_test)
print('3:400 '+str(acc))

model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(5, input_shape=(5, )))
model.add(tf.keras.layers.Dense(16, activation="relu"))
model.add(tf.keras.layers.Dense(10, activation="relu"))
model.add(tf.keras.layers.Dense(5, activation="relu"))
model.add(tf.keras.layers.Dense(1, activation="sigmoid"))
model.compile(optimizer=opt, metrics='accuracy', loss='mse')
model.fit(x_train, y_train, batch_size=15, epochs=800, verbose=0, validation_data=(x_test, y_test))
_, acc = model.evaluate(x_test, y_test)
print('3:800 '+str(acc))
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1288 - accuracy: 0.8229
# 3:200 0.822857141494751
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1366 - accuracy: 0.7886
# 3:400 0.7885714173316956
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1282 - accuracy: 0.8343
# 3:800 0.8342857360839844
