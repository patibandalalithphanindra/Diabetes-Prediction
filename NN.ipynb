# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf

# %%
data = pd.read_csv('/content/dataset.csv')

# %%
from sklearn.model_selection import train_test_split
x = data.iloc[:,:-1]
y = data.iloc[:,-1]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=5)

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(5, input_shape=(5, )))
model.add(tf.keras.layers.Dense(5, activation="relu"))
model.add(tf.keras.layers.Dense(1, activation="sigmoid"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 30
#
#  dense_1 (Dense)             (None, 5)                 30
#
#  dense_2 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 66
# Trainable params: 66
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import SGD

opt = SGD(lr=0.01, momentum=0.9)

model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(5, input_shape=(5, )))
model.add(tf.keras.layers.Dense(5, activation="relu"))
model.add(tf.keras.layers.Dense(1, activation="sigmoid"))
model.compile(optimizer=opt, metrics='accuracy', loss='mse')

checkpoint = ModelCheckpoint('/content/checkpts_1_200.hdf5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

model.fit(x_train, y_train, batch_size=15, epochs=200, verbose=0, validation_data=(x_test, y_test), callbacks=callbacks_list)
model.load_weights("checkpts_1_200.hdf5")
_, acc = model.evaluate(x_test, y_test)
print('1:200 '+str(acc))

model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(5, input_shape=(5, )))
model.add(tf.keras.layers.Dense(5, activation="relu"))
model.add(tf.keras.layers.Dense(1, activation="sigmoid"))
model.compile(optimizer=opt, metrics='accuracy', loss='mse')

checkpoint = ModelCheckpoint('/content/checkpts_1_400.hdf5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

model.fit(x_train, y_train, batch_size=15, epochs=400, verbose=0, validation_data=(x_test, y_test), callbacks=callbacks_list)
model.load_weights("checkpts_1_400.hdf5")
_, acc = model.evaluate(x_test, y_test)
print('1:400 '+str(acc))

model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(5, input_shape=(5, )))
model.add(tf.keras.layers.Dense(5, activation="relu"))
model.add(tf.keras.layers.Dense(1, activation="sigmoid"))
model.compile(optimizer=opt, metrics='accuracy', loss='mse')

checkpoint = ModelCheckpoint('/content/checkpts_1_800.hdf5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

model.fit(x_train, y_train, batch_size=15, epochs=800, verbose=0, validation_data=(x_test, y_test), callbacks=callbacks_list)
model.load_weights("checkpts_1_800.hdf5")
_, acc = model.evaluate(x_test, y_test)
print('1:800 '+str(acc))
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# Epoch 1: val_accuracy improved from -inf to 0.69143, saving model to /content/checkpts_1_200.hdf5
#
# Epoch 2: val_accuracy did not improve from 0.69143
#
# Epoch 3: val_accuracy did not improve from 0.69143
#
# Epoch 4: val_accuracy improved from 0.69143 to 0.69714, saving model to /content/checkpts_1_200.hdf5
#
# Epoch 5: val_accuracy improved from 0.69714 to 0.71429, saving model to /content/checkpts_1_200.hdf5
#
# Epoch 6: val_accuracy improved from 0.71429 to 0.73714, saving model to /content/checkpts_1_200.hdf5
#
# Epoch 7: val_accuracy improved from 0.73714 to 0.74286, saving model to /content/checkpts_1_200.hdf5
#
# Epoch 8: val_accuracy improved from 0.74286 to 0.77143, saving model to /content/checkpts_1_200.hdf5
#
# Epoch 9: val_accuracy improved from 0.77143 to 0.78857, saving model to /content/checkpts_1_200.hdf5
#
# Epoch 10: val_accuracy did not improve from 0.78857
#
# Epoch 11: val_accuracy did not improve from 0.78857
#
# Epoch 12: val_accuracy improved from 0.78857 to 0.81143, saving model to /content/checkpts_1_200.hdf5
#
# Epoch 13: val_accuracy improved from 0.81143 to 0.82286, saving model to /content/checkpts_1_200.hdf5
#
# Epoch 14: val_accuracy did not improve from 0.82286
#
# Epoch 15: val_accuracy did not improve from 0.82286
#
# Epoch 16: val_accuracy did not improve from 0.82286
#
# Epoch 17: val_accuracy did not improve from 0.82286
#
# Epoch 18: val_accuracy improved from 0.82286 to 0.82857, saving model to /content/checkpts_1_200.hdf5
#
# Epoch 19: val_accuracy did not improve from 0.82857
#
# Epoch 20: val_accuracy improved from 0.82857 to 0.83429, saving model to /content/checkpts_1_200.hdf5
#
# Epoch 21: val_accuracy did not improve from 0.83429
#
# Epoch 22: val_accuracy did not improve from 0.83429
#
# Epoch 23: val_accuracy did not improve from 0.83429
#
# Epoch 24: val_accuracy did not improve from 0.83429
#
# Epoch 25: val_accuracy did not improve from 0.83429
#
# Epoch 26: val_accuracy did not improve from 0.83429
#
# Epoch 27: val_accuracy did not improve from 0.83429
#
# Epoch 28: val_accuracy did not improve from 0.83429
#
# Epoch 29: val_accuracy did not improve from 0.83429
#
# Epoch 30: val_accuracy did not improve from 0.83429
#
# Epoch 31: val_accuracy did not improve from 0.83429
#
# Epoch 32: val_accuracy improved from 0.83429 to 0.84000, saving model to /content/checkpts_1_200.hdf5
#
# Epoch 33: val_accuracy did not improve from 0.84000
#
# Epoch 34: val_accuracy did not improve from 0.84000
#
# Epoch 35: val_accuracy did not improve from 0.84000
#
# Epoch 36: val_accuracy did not improve from 0.84000
#
# Epoch 37: val_accuracy did not improve from 0.84000
#
# Epoch 38: val_accuracy did not improve from 0.84000
#
# Epoch 39: val_accuracy did not improve from 0.84000
#
# Epoch 40: val_accuracy did not improve from 0.84000
#
# Epoch 41: val_accuracy did not improve from 0.84000
#
# Epoch 42: val_accuracy did not improve from 0.84000
#
# Epoch 43: val_accuracy did not improve from 0.84000
#
# Epoch 44: val_accuracy did not improve from 0.84000
#
# Epoch 45: val_accuracy did not improve from 0.84000
#
# Epoch 46: val_accuracy did not improve from 0.84000
#
# Epoch 47: val_accuracy did not improve from 0.84000
#
# Epoch 48: val_accuracy did not improve from 0.84000
#
# Epoch 49: val_accuracy did not improve from 0.84000
#
# Epoch 50: val_accuracy did not improve from 0.84000
#
# Epoch 51: val_accuracy did not improve from 0.84000
#
# Epoch 52: val_accuracy did not improve from 0.84000
#
# Epoch 53: val_accuracy did not improve from 0.84000
#
# Epoch 54: val_accuracy did not improve from 0.84000
#
# Epoch 55: val_accuracy did not improve from 0.84000
#
# Epoch 56: val_accuracy did not improve from 0.84000
#
# Epoch 57: val_accuracy did not improve from 0.84000
#
# Epoch 58: val_accuracy did not improve from 0.84000
#
# Epoch 59: val_accuracy did not improve from 0.84000
#
# Epoch 60: val_accuracy did not improve from 0.84000
#
# Epoch 61: val_accuracy did not improve from 0.84000
#
# Epoch 62: val_accuracy did not improve from 0.84000
#
# Epoch 63: val_accuracy did not improve from 0.84000
#
# Epoch 64: val_accuracy did not improve from 0.84000
#
# Epoch 65: val_accuracy did not improve from 0.84000
#
# Epoch 66: val_accuracy did not improve from 0.84000
#
# Epoch 67: val_accuracy did not improve from 0.84000
#
# Epoch 68: val_accuracy did not improve from 0.84000
#
# Epoch 69: val_accuracy did not improve from 0.84000
#
# Epoch 70: val_accuracy did not improve from 0.84000
#
# Epoch 71: val_accuracy did not improve from 0.84000
#
# Epoch 72: val_accuracy improved from 0.84000 to 0.84571, saving model to /content/checkpts_1_200.hdf5
#
# Epoch 73: val_accuracy did not improve from 0.84571
#
# Epoch 74: val_accuracy did not improve from 0.84571
#
# Epoch 75: val_accuracy did not improve from 0.84571
#
# Epoch 76: val_accuracy did not improve from 0.84571
#
# Epoch 77: val_accuracy did not improve from 0.84571
#
# Epoch 78: val_accuracy did not improve from 0.84571
#
# Epoch 79: val_accuracy did not improve from 0.84571
#
# Epoch 80: val_accuracy did not improve from 0.84571
#
# Epoch 81: val_accuracy did not improve from 0.84571
#
# Epoch 82: val_accuracy did not improve from 0.84571
#
# Epoch 83: val_accuracy did not improve from 0.84571
#
# Epoch 84: val_accuracy did not improve from 0.84571
#
# Epoch 85: val_accuracy did not improve from 0.84571
#
# Epoch 86: val_accuracy did not improve from 0.84571
#
# Epoch 87: val_accuracy did not improve from 0.84571
#
# Epoch 88: val_accuracy did not improve from 0.84571
#
# Epoch 89: val_accuracy did not improve from 0.84571
#
# Epoch 90: val_accuracy did not improve from 0.84571
#
# Epoch 91: val_accuracy did not improve from 0.84571
#
# Epoch 92: val_accuracy did not improve from 0.84571
#
# Epoch 93: val_accuracy did not improve from 0.84571
#
# Epoch 94: val_accuracy did not improve from 0.84571
#
# Epoch 95: val_accuracy did not improve from 0.84571
#
# Epoch 96: val_accuracy did not improve from 0.84571
#
# Epoch 97: val_accuracy did not improve from 0.84571
#
# Epoch 98: val_accuracy did not improve from 0.84571
#
# Epoch 99: val_accuracy did not improve from 0.84571
#
# Epoch 100: val_accuracy did not improve from 0.84571
#
# Epoch 101: val_accuracy did not improve from 0.84571
#
# Epoch 102: val_accuracy did not improve from 0.84571
#
# Epoch 103: val_accuracy did not improve from 0.84571
#
# Epoch 104: val_accuracy did not improve from 0.84571
#
# Epoch 105: val_accuracy did not improve from 0.84571
#
# Epoch 106: val_accuracy did not improve from 0.84571
#
# Epoch 107: val_accuracy did not improve from 0.84571
#
# Epoch 108: val_accuracy did not improve from 0.84571
#
# Epoch 109: val_accuracy did not improve from 0.84571
#
# Epoch 110: val_accuracy did not improve from 0.84571
#
# Epoch 111: val_accuracy did not improve from 0.84571
#
# Epoch 112: val_accuracy did not improve from 0.84571
#
# Epoch 113: val_accuracy did not improve from 0.84571
#
# Epoch 114: val_accuracy did not improve from 0.84571
#
# Epoch 115: val_accuracy did not improve from 0.84571
#
# Epoch 116: val_accuracy did not improve from 0.84571
#
# Epoch 117: val_accuracy did not improve from 0.84571
#
# Epoch 118: val_accuracy did not improve from 0.84571
#
# Epoch 119: val_accuracy did not improve from 0.84571
#
# Epoch 120: val_accuracy did not improve from 0.84571
#
# Epoch 121: val_accuracy did not improve from 0.84571
#
# Epoch 122: val_accuracy did not improve from 0.84571
#
# Epoch 123: val_accuracy did not improve from 0.84571
#
# Epoch 124: val_accuracy did not improve from 0.84571
#
# Epoch 125: val_accuracy did not improve from 0.84571
#
# Epoch 126: val_accuracy did not improve from 0.84571
#
# Epoch 127: val_accuracy did not improve from 0.84571
#
# Epoch 128: val_accuracy did not improve from 0.84571
#
# Epoch 129: val_accuracy did not improve from 0.84571
#
# Epoch 130: val_accuracy did not improve from 0.84571
#
# Epoch 131: val_accuracy did not improve from 0.84571
#
# Epoch 132: val_accuracy did not improve from 0.84571
#
# Epoch 133: val_accuracy did not improve from 0.84571
#
# Epoch 134: val_accuracy did not improve from 0.84571
#
# Epoch 135: val_accuracy did not improve from 0.84571
#
# Epoch 136: val_accuracy did not improve from 0.84571
#
# Epoch 137: val_accuracy did not improve from 0.84571
#
# Epoch 138: val_accuracy did not improve from 0.84571
#
# Epoch 139: val_accuracy did not improve from 0.84571
#
# Epoch 140: val_accuracy did not improve from 0.84571
#
# Epoch 141: val_accuracy did not improve from 0.84571
#
# Epoch 142: val_accuracy did not improve from 0.84571
#
# Epoch 143: val_accuracy did not improve from 0.84571
#
# Epoch 144: val_accuracy did not improve from 0.84571
#
# Epoch 145: val_accuracy did not improve from 0.84571
#
# Epoch 146: val_accuracy did not improve from 0.84571
#
# Epoch 147: val_accuracy did not improve from 0.84571
#
# Epoch 148: val_accuracy did not improve from 0.84571
#
# Epoch 149: val_accuracy did not improve from 0.84571
#
# Epoch 150: val_accuracy did not improve from 0.84571
#
# Epoch 151: val_accuracy did not improve from 0.84571
#
# Epoch 152: val_accuracy did not improve from 0.84571
#
# Epoch 153: val_accuracy did not improve from 0.84571
#
# Epoch 154: val_accuracy did not improve from 0.84571
#
# Epoch 155: val_accuracy did not improve from 0.84571
#
# Epoch 156: val_accuracy did not improve from 0.84571
#
# Epoch 157: val_accuracy did not improve from 0.84571
#
# Epoch 158: val_accuracy did not improve from 0.84571
#
# Epoch 159: val_accuracy did not improve from 0.84571
#
# Epoch 160: val_accuracy did not improve from 0.84571
#
# Epoch 161: val_accuracy did not improve from 0.84571
#
# Epoch 162: val_accuracy did not improve from 0.84571
#
# Epoch 163: val_accuracy did not improve from 0.84571
#
# Epoch 164: val_accuracy did not improve from 0.84571
#
# Epoch 165: val_accuracy did not improve from 0.84571
#
# Epoch 166: val_accuracy did not improve from 0.84571
#
# Epoch 167: val_accuracy did not improve from 0.84571
#
# Epoch 168: val_accuracy did not improve from 0.84571
#
# Epoch 169: val_accuracy did not improve from 0.84571
#
# Epoch 170: val_accuracy did not improve from 0.84571
#
# Epoch 171: val_accuracy did not improve from 0.84571
#
# Epoch 172: val_accuracy did not improve from 0.84571
#
# Epoch 173: val_accuracy did not improve from 0.84571
#
# Epoch 174: val_accuracy did not improve from 0.84571
#
# Epoch 175: val_accuracy did not improve from 0.84571
#
# Epoch 176: val_accuracy did not improve from 0.84571
#
# Epoch 177: val_accuracy did not improve from 0.84571
#
# Epoch 178: val_accuracy did not improve from 0.84571
#
# Epoch 179: val_accuracy did not improve from 0.84571
#
# Epoch 180: val_accuracy did not improve from 0.84571
#
# Epoch 181: val_accuracy did not improve from 0.84571
#
# Epoch 182: val_accuracy did not improve from 0.84571
#
# Epoch 183: val_accuracy did not improve from 0.84571
#
# Epoch 184: val_accuracy did not improve from 0.84571
#
# Epoch 185: val_accuracy did not improve from 0.84571
#
# Epoch 186: val_accuracy did not improve from 0.84571
#
# Epoch 187: val_accuracy did not improve from 0.84571
#
# Epoch 188: val_accuracy did not improve from 0.84571
#
# Epoch 189: val_accuracy did not improve from 0.84571
#
# Epoch 190: val_accuracy did not improve from 0.84571
#
# Epoch 191: val_accuracy did not improve from 0.84571
#
# Epoch 192: val_accuracy did not improve from 0.84571
#
# Epoch 193: val_accuracy did not improve from 0.84571
#
# Epoch 194: val_accuracy did not improve from 0.84571
#
# Epoch 195: val_accuracy did not improve from 0.84571
#
# Epoch 196: val_accuracy did not improve from 0.84571
#
# Epoch 197: val_accuracy did not improve from 0.84571
#
# Epoch 198: val_accuracy did not improve from 0.84571
#
# Epoch 199: val_accuracy did not improve from 0.84571
#
# Epoch 200: val_accuracy did not improve from 0.84571
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1289 - accuracy: 0.8457
# 1:200 0.845714271068573
#
# Epoch 1: val_accuracy improved from -inf to 0.71429, saving model to /content/checkpts_1_400.hdf5
#
# Epoch 2: val_accuracy did not improve from 0.71429
#
# Epoch 3: val_accuracy did not improve from 0.71429
#
# Epoch 4: val_accuracy did not improve from 0.71429
#
# Epoch 5: val_accuracy improved from 0.71429 to 0.73143, saving model to /content/checkpts_1_400.hdf5
#
# Epoch 6: val_accuracy improved from 0.73143 to 0.73714, saving model to /content/checkpts_1_400.hdf5
#
# Epoch 7: val_accuracy improved from 0.73714 to 0.76571, saving model to /content/checkpts_1_400.hdf5
#
# Epoch 8: val_accuracy improved from 0.76571 to 0.77143, saving model to /content/checkpts_1_400.hdf5
#
# Epoch 9: val_accuracy improved from 0.77143 to 0.81143, saving model to /content/checkpts_1_400.hdf5
#
# Epoch 10: val_accuracy improved from 0.81143 to 0.82286, saving model to /content/checkpts_1_400.hdf5
#
# Epoch 11: val_accuracy did not improve from 0.82286
#
# Epoch 12: val_accuracy did not improve from 0.82286
#
# Epoch 13: val_accuracy improved from 0.82286 to 0.84000, saving model to /content/checkpts_1_400.hdf5
#
# Epoch 14: val_accuracy improved from 0.84000 to 0.84571, saving model to /content/checkpts_1_400.hdf5
#
# Epoch 15: val_accuracy did not improve from 0.84571
#
# Epoch 16: val_accuracy did not improve from 0.84571
#
# Epoch 17: val_accuracy did not improve from 0.84571
#
# Epoch 18: val_accuracy did not improve from 0.84571
#
# Epoch 19: val_accuracy did not improve from 0.84571
#
# Epoch 20: val_accuracy did not improve from 0.84571
#
# Epoch 21: val_accuracy did not improve from 0.84571
#
# Epoch 22: val_accuracy did not improve from 0.84571
#
# Epoch 23: val_accuracy did not improve from 0.84571
#
# Epoch 24: val_accuracy did not improve from 0.84571
#
# Epoch 25: val_accuracy did not improve from 0.84571
#
# Epoch 26: val_accuracy did not improve from 0.84571
#
# Epoch 27: val_accuracy did not improve from 0.84571
#
# Epoch 28: val_accuracy did not improve from 0.84571
#
# Epoch 29: val_accuracy did not improve from 0.84571
#
# Epoch 30: val_accuracy did not improve from 0.84571
#
# Epoch 31: val_accuracy did not improve from 0.84571
#
# Epoch 32: val_accuracy did not improve from 0.84571
#
# Epoch 33: val_accuracy did not improve from 0.84571
#
# Epoch 34: val_accuracy did not improve from 0.84571
#
# Epoch 35: val_accuracy did not improve from 0.84571
#
# Epoch 36: val_accuracy did not improve from 0.84571
#
# Epoch 37: val_accuracy did not improve from 0.84571
#
# Epoch 38: val_accuracy did not improve from 0.84571
#
# Epoch 39: val_accuracy did not improve from 0.84571
#
# Epoch 40: val_accuracy did not improve from 0.84571
#
# Epoch 41: val_accuracy did not improve from 0.84571
#
# Epoch 42: val_accuracy did not improve from 0.84571
#
# Epoch 43: val_accuracy did not improve from 0.84571
#
# Epoch 44: val_accuracy did not improve from 0.84571
#
# Epoch 45: val_accuracy did not improve from 0.84571
#
# Epoch 46: val_accuracy did not improve from 0.84571
#
# Epoch 47: val_accuracy did not improve from 0.84571
#
# Epoch 48: val_accuracy did not improve from 0.84571
#
# Epoch 49: val_accuracy did not improve from 0.84571
#
# Epoch 50: val_accuracy did not improve from 0.84571
#
# Epoch 51: val_accuracy did not improve from 0.84571
#
# Epoch 52: val_accuracy did not improve from 0.84571
#
# Epoch 53: val_accuracy did not improve from 0.84571
#
# Epoch 54: val_accuracy did not improve from 0.84571
#
# Epoch 55: val_accuracy did not improve from 0.84571
#
# Epoch 56: val_accuracy did not improve from 0.84571
#
# Epoch 57: val_accuracy did not improve from 0.84571
#
# Epoch 58: val_accuracy did not improve from 0.84571
#
# Epoch 59: val_accuracy did not improve from 0.84571
#
# Epoch 60: val_accuracy did not improve from 0.84571
#
# Epoch 61: val_accuracy did not improve from 0.84571
#
# Epoch 62: val_accuracy did not improve from 0.84571
#
# Epoch 63: val_accuracy did not improve from 0.84571
#
# Epoch 64: val_accuracy did not improve from 0.84571
#
# Epoch 65: val_accuracy did not improve from 0.84571
#
# Epoch 66: val_accuracy did not improve from 0.84571
#
# Epoch 67: val_accuracy did not improve from 0.84571
#
# Epoch 68: val_accuracy did not improve from 0.84571
#
# Epoch 69: val_accuracy did not improve from 0.84571
#
# Epoch 70: val_accuracy did not improve from 0.84571
#
# Epoch 71: val_accuracy did not improve from 0.84571
#
# Epoch 72: val_accuracy did not improve from 0.84571
#
# Epoch 73: val_accuracy did not improve from 0.84571
#
# Epoch 74: val_accuracy did not improve from 0.84571
#
# Epoch 75: val_accuracy did not improve from 0.84571
#
# Epoch 76: val_accuracy did not improve from 0.84571
#
# Epoch 77: val_accuracy did not improve from 0.84571
#
# Epoch 78: val_accuracy did not improve from 0.84571
#
# Epoch 79: val_accuracy did not improve from 0.84571
#
# Epoch 80: val_accuracy did not improve from 0.84571
#
# Epoch 81: val_accuracy did not improve from 0.84571
#
# Epoch 82: val_accuracy did not improve from 0.84571
#
# Epoch 83: val_accuracy did not improve from 0.84571
#
# Epoch 84: val_accuracy did not improve from 0.84571
#
# Epoch 85: val_accuracy did not improve from 0.84571
#
# Epoch 86: val_accuracy did not improve from 0.84571
#
# Epoch 87: val_accuracy did not improve from 0.84571
#
# Epoch 88: val_accuracy did not improve from 0.84571
#
# Epoch 89: val_accuracy did not improve from 0.84571
#
# Epoch 90: val_accuracy did not improve from 0.84571
#
# Epoch 91: val_accuracy did not improve from 0.84571
#
# Epoch 92: val_accuracy did not improve from 0.84571
#
# Epoch 93: val_accuracy did not improve from 0.84571
#
# Epoch 94: val_accuracy did not improve from 0.84571
#
# Epoch 95: val_accuracy did not improve from 0.84571
#
# Epoch 96: val_accuracy did not improve from 0.84571
#
# Epoch 97: val_accuracy did not improve from 0.84571
#
# Epoch 98: val_accuracy did not improve from 0.84571
#
# Epoch 99: val_accuracy did not improve from 0.84571
#
# Epoch 100: val_accuracy did not improve from 0.84571
#
# Epoch 101: val_accuracy did not improve from 0.84571
#
# Epoch 102: val_accuracy did not improve from 0.84571
#
# Epoch 103: val_accuracy did not improve from 0.84571
#
# Epoch 104: val_accuracy did not improve from 0.84571
#
# Epoch 105: val_accuracy did not improve from 0.84571
#
# Epoch 106: val_accuracy did not improve from 0.84571
#
# Epoch 107: val_accuracy did not improve from 0.84571
#
# Epoch 108: val_accuracy did not improve from 0.84571
#
# Epoch 109: val_accuracy did not improve from 0.84571
#
# Epoch 110: val_accuracy did not improve from 0.84571
#
# Epoch 111: val_accuracy did not improve from 0.84571
#
# Epoch 112: val_accuracy did not improve from 0.84571
#
# Epoch 113: val_accuracy did not improve from 0.84571
#
# Epoch 114: val_accuracy did not improve from 0.84571
#
# Epoch 115: val_accuracy did not improve from 0.84571
#
# Epoch 116: val_accuracy did not improve from 0.84571
#
# Epoch 117: val_accuracy did not improve from 0.84571
#
# Epoch 118: val_accuracy did not improve from 0.84571
#
# Epoch 119: val_accuracy did not improve from 0.84571
#
# Epoch 120: val_accuracy did not improve from 0.84571
#
# Epoch 121: val_accuracy did not improve from 0.84571
#
# Epoch 122: val_accuracy did not improve from 0.84571
#
# Epoch 123: val_accuracy did not improve from 0.84571
#
# Epoch 124: val_accuracy did not improve from 0.84571
#
# Epoch 125: val_accuracy did not improve from 0.84571
#
# Epoch 126: val_accuracy did not improve from 0.84571
#
# Epoch 127: val_accuracy did not improve from 0.84571
#
# Epoch 128: val_accuracy did not improve from 0.84571
#
# Epoch 129: val_accuracy did not improve from 0.84571
#
# Epoch 130: val_accuracy did not improve from 0.84571
#
# Epoch 131: val_accuracy did not improve from 0.84571
#
# Epoch 132: val_accuracy did not improve from 0.84571
#
# Epoch 133: val_accuracy did not improve from 0.84571
#
# Epoch 134: val_accuracy did not improve from 0.84571
#
# Epoch 135: val_accuracy did not improve from 0.84571
#
# Epoch 136: val_accuracy did not improve from 0.84571
#
# Epoch 137: val_accuracy did not improve from 0.84571
#
# Epoch 138: val_accuracy did not improve from 0.84571
#
# Epoch 139: val_accuracy did not improve from 0.84571
#
# Epoch 140: val_accuracy did not improve from 0.84571
#
# Epoch 141: val_accuracy did not improve from 0.84571
#
# Epoch 142: val_accuracy did not improve from 0.84571
#
# Epoch 143: val_accuracy did not improve from 0.84571
#
# Epoch 144: val_accuracy did not improve from 0.84571
#
# Epoch 145: val_accuracy did not improve from 0.84571
#
# Epoch 146: val_accuracy did not improve from 0.84571
#
# Epoch 147: val_accuracy did not improve from 0.84571
#
# Epoch 148: val_accuracy did not improve from 0.84571
#
# Epoch 149: val_accuracy did not improve from 0.84571
#
# Epoch 150: val_accuracy did not improve from 0.84571
#
# Epoch 151: val_accuracy did not improve from 0.84571
#
# Epoch 152: val_accuracy did not improve from 0.84571
#
# Epoch 153: val_accuracy did not improve from 0.84571
#
# Epoch 154: val_accuracy did not improve from 0.84571
#
# Epoch 155: val_accuracy did not improve from 0.84571
#
# Epoch 156: val_accuracy did not improve from 0.84571
#
# Epoch 157: val_accuracy did not improve from 0.84571
#
# Epoch 158: val_accuracy did not improve from 0.84571
#
# Epoch 159: val_accuracy did not improve from 0.84571
#
# Epoch 160: val_accuracy did not improve from 0.84571
#
# Epoch 161: val_accuracy did not improve from 0.84571
#
# Epoch 162: val_accuracy did not improve from 0.84571
#
# Epoch 163: val_accuracy did not improve from 0.84571
#
# Epoch 164: val_accuracy did not improve from 0.84571
#
# Epoch 165: val_accuracy did not improve from 0.84571
#
# Epoch 166: val_accuracy did not improve from 0.84571
#
# Epoch 167: val_accuracy did not improve from 0.84571
#
# Epoch 168: val_accuracy did not improve from 0.84571
#
# Epoch 169: val_accuracy did not improve from 0.84571
#
# Epoch 170: val_accuracy did not improve from 0.84571
#
# Epoch 171: val_accuracy did not improve from 0.84571
#
# Epoch 172: val_accuracy did not improve from 0.84571
#
# Epoch 173: val_accuracy did not improve from 0.84571
#
# Epoch 174: val_accuracy did not improve from 0.84571
#
# Epoch 175: val_accuracy did not improve from 0.84571
#
# Epoch 176: val_accuracy did not improve from 0.84571
#
# Epoch 177: val_accuracy did not improve from 0.84571
#
# Epoch 178: val_accuracy did not improve from 0.84571
#
# Epoch 179: val_accuracy did not improve from 0.84571
#
# Epoch 180: val_accuracy did not improve from 0.84571
#
# Epoch 181: val_accuracy did not improve from 0.84571
#
# Epoch 182: val_accuracy did not improve from 0.84571
#
# Epoch 183: val_accuracy did not improve from 0.84571
#
# Epoch 184: val_accuracy did not improve from 0.84571
#
# Epoch 185: val_accuracy did not improve from 0.84571
#
# Epoch 186: val_accuracy did not improve from 0.84571
#
# Epoch 187: val_accuracy did not improve from 0.84571
#
# Epoch 188: val_accuracy did not improve from 0.84571
#
# Epoch 189: val_accuracy did not improve from 0.84571
#
# Epoch 190: val_accuracy did not improve from 0.84571
#
# Epoch 191: val_accuracy did not improve from 0.84571
#
# Epoch 192: val_accuracy did not improve from 0.84571
#
# Epoch 193: val_accuracy did not improve from 0.84571
#
# Epoch 194: val_accuracy did not improve from 0.84571
#
# Epoch 195: val_accuracy did not improve from 0.84571
#
# Epoch 196: val_accuracy did not improve from 0.84571
#
# Epoch 197: val_accuracy did not improve from 0.84571
#
# Epoch 198: val_accuracy did not improve from 0.84571
#
# Epoch 199: val_accuracy did not improve from 0.84571
#
# Epoch 200: val_accuracy did not improve from 0.84571
#
# Epoch 201: val_accuracy did not improve from 0.84571
#
# Epoch 202: val_accuracy did not improve from 0.84571
#
# Epoch 203: val_accuracy did not improve from 0.84571
#
# Epoch 204: val_accuracy did not improve from 0.84571
#
# Epoch 205: val_accuracy did not improve from 0.84571
#
# Epoch 206: val_accuracy did not improve from 0.84571
#
# Epoch 207: val_accuracy did not improve from 0.84571
#
# Epoch 208: val_accuracy did not improve from 0.84571
#
# Epoch 209: val_accuracy did not improve from 0.84571
#
# Epoch 210: val_accuracy did not improve from 0.84571
#
# Epoch 211: val_accuracy did not improve from 0.84571
#
# Epoch 212: val_accuracy did not improve from 0.84571
#
# Epoch 213: val_accuracy did not improve from 0.84571
#
# Epoch 214: val_accuracy did not improve from 0.84571
#
# Epoch 215: val_accuracy did not improve from 0.84571
#
# Epoch 216: val_accuracy did not improve from 0.84571
#
# Epoch 217: val_accuracy did not improve from 0.84571
#
# Epoch 218: val_accuracy did not improve from 0.84571
#
# Epoch 219: val_accuracy did not improve from 0.84571
#
# Epoch 220: val_accuracy did not improve from 0.84571
#
# Epoch 221: val_accuracy did not improve from 0.84571
#
# Epoch 222: val_accuracy did not improve from 0.84571
#
# Epoch 223: val_accuracy did not improve from 0.84571
#
# Epoch 224: val_accuracy did not improve from 0.84571
#
# Epoch 225: val_accuracy did not improve from 0.84571
#
# Epoch 226: val_accuracy did not improve from 0.84571
#
# Epoch 227: val_accuracy did not improve from 0.84571
#
# Epoch 228: val_accuracy did not improve from 0.84571
#
# Epoch 229: val_accuracy did not improve from 0.84571
#
# Epoch 230: val_accuracy did not improve from 0.84571
#
# Epoch 231: val_accuracy did not improve from 0.84571
#
# Epoch 232: val_accuracy did not improve from 0.84571
#
# Epoch 233: val_accuracy did not improve from 0.84571
#
# Epoch 234: val_accuracy did not improve from 0.84571
#
# Epoch 235: val_accuracy did not improve from 0.84571
#
# Epoch 236: val_accuracy did not improve from 0.84571
#
# Epoch 237: val_accuracy did not improve from 0.84571
#
# Epoch 238: val_accuracy did not improve from 0.84571
#
# Epoch 239: val_accuracy did not improve from 0.84571
#
# Epoch 240: val_accuracy did not improve from 0.84571
#
# Epoch 241: val_accuracy did not improve from 0.84571
#
# Epoch 242: val_accuracy did not improve from 0.84571
#
# Epoch 243: val_accuracy did not improve from 0.84571
#
# Epoch 244: val_accuracy did not improve from 0.84571
#
# Epoch 245: val_accuracy did not improve from 0.84571
#
# Epoch 246: val_accuracy did not improve from 0.84571
#
# Epoch 247: val_accuracy did not improve from 0.84571
#
# Epoch 248: val_accuracy did not improve from 0.84571
#
# Epoch 249: val_accuracy did not improve from 0.84571
#
# Epoch 250: val_accuracy did not improve from 0.84571
#
# Epoch 251: val_accuracy did not improve from 0.84571
#
# Epoch 252: val_accuracy did not improve from 0.84571
#
# Epoch 253: val_accuracy did not improve from 0.84571
#
# Epoch 254: val_accuracy did not improve from 0.84571
#
# Epoch 255: val_accuracy did not improve from 0.84571
#
# Epoch 256: val_accuracy did not improve from 0.84571
#
# Epoch 257: val_accuracy did not improve from 0.84571
#
# Epoch 258: val_accuracy did not improve from 0.84571
#
# Epoch 259: val_accuracy did not improve from 0.84571
#
# Epoch 260: val_accuracy did not improve from 0.84571
#
# Epoch 261: val_accuracy did not improve from 0.84571
#
# Epoch 262: val_accuracy did not improve from 0.84571
#
# Epoch 263: val_accuracy did not improve from 0.84571
#
# Epoch 264: val_accuracy did not improve from 0.84571
#
# Epoch 265: val_accuracy did not improve from 0.84571
#
# Epoch 266: val_accuracy did not improve from 0.84571
#
# Epoch 267: val_accuracy did not improve from 0.84571
#
# Epoch 268: val_accuracy did not improve from 0.84571
#
# Epoch 269: val_accuracy did not improve from 0.84571
#
# Epoch 270: val_accuracy did not improve from 0.84571
#
# Epoch 271: val_accuracy did not improve from 0.84571
#
# Epoch 272: val_accuracy did not improve from 0.84571
#
# Epoch 273: val_accuracy did not improve from 0.84571
#
# Epoch 274: val_accuracy did not improve from 0.84571
#
# Epoch 275: val_accuracy did not improve from 0.84571
#
# Epoch 276: val_accuracy did not improve from 0.84571
#
# Epoch 277: val_accuracy did not improve from 0.84571
#
# Epoch 278: val_accuracy did not improve from 0.84571
#
# Epoch 279: val_accuracy did not improve from 0.84571
#
# Epoch 280: val_accuracy did not improve from 0.84571
#
# Epoch 281: val_accuracy did not improve from 0.84571
#
# Epoch 282: val_accuracy did not improve from 0.84571
#
# Epoch 283: val_accuracy did not improve from 0.84571
#
# Epoch 284: val_accuracy did not improve from 0.84571
#
# Epoch 285: val_accuracy did not improve from 0.84571
#
# Epoch 286: val_accuracy did not improve from 0.84571
#
# Epoch 287: val_accuracy did not improve from 0.84571
#
# Epoch 288: val_accuracy did not improve from 0.84571
#
# Epoch 289: val_accuracy did not improve from 0.84571
#
# Epoch 290: val_accuracy did not improve from 0.84571
#
# Epoch 291: val_accuracy did not improve from 0.84571
#
# Epoch 292: val_accuracy did not improve from 0.84571
#
# Epoch 293: val_accuracy did not improve from 0.84571
#
# Epoch 294: val_accuracy did not improve from 0.84571
#
# Epoch 295: val_accuracy did not improve from 0.84571
#
# Epoch 296: val_accuracy did not improve from 0.84571
#
# Epoch 297: val_accuracy did not improve from 0.84571
#
# Epoch 298: val_accuracy did not improve from 0.84571
#
# Epoch 299: val_accuracy did not improve from 0.84571
#
# Epoch 300: val_accuracy did not improve from 0.84571
#
# Epoch 301: val_accuracy did not improve from 0.84571
#
# Epoch 302: val_accuracy did not improve from 0.84571
#
# Epoch 303: val_accuracy did not improve from 0.84571
#
# Epoch 304: val_accuracy did not improve from 0.84571
#
# Epoch 305: val_accuracy did not improve from 0.84571
#
# Epoch 306: val_accuracy did not improve from 0.84571
#
# Epoch 307: val_accuracy did not improve from 0.84571
#
# Epoch 308: val_accuracy did not improve from 0.84571
#
# Epoch 309: val_accuracy did not improve from 0.84571
#
# Epoch 310: val_accuracy did not improve from 0.84571
#
# Epoch 311: val_accuracy did not improve from 0.84571
#
# Epoch 312: val_accuracy did not improve from 0.84571
#
# Epoch 313: val_accuracy did not improve from 0.84571
#
# Epoch 314: val_accuracy did not improve from 0.84571
#
# Epoch 315: val_accuracy did not improve from 0.84571
#
# Epoch 316: val_accuracy did not improve from 0.84571
#
# Epoch 317: val_accuracy did not improve from 0.84571
#
# Epoch 318: val_accuracy did not improve from 0.84571
#
# Epoch 319: val_accuracy did not improve from 0.84571
#
# Epoch 320: val_accuracy did not improve from 0.84571
#
# Epoch 321: val_accuracy did not improve from 0.84571
#
# Epoch 322: val_accuracy did not improve from 0.84571
#
# Epoch 323: val_accuracy did not improve from 0.84571
#
# Epoch 324: val_accuracy did not improve from 0.84571
#
# Epoch 325: val_accuracy did not improve from 0.84571
#
# Epoch 326: val_accuracy did not improve from 0.84571
#
# Epoch 327: val_accuracy did not improve from 0.84571
#
# Epoch 328: val_accuracy did not improve from 0.84571
#
# Epoch 329: val_accuracy did not improve from 0.84571
#
# Epoch 330: val_accuracy did not improve from 0.84571
#
# Epoch 331: val_accuracy did not improve from 0.84571
#
# Epoch 332: val_accuracy did not improve from 0.84571
#
# Epoch 333: val_accuracy did not improve from 0.84571
#
# Epoch 334: val_accuracy did not improve from 0.84571
#
# Epoch 335: val_accuracy did not improve from 0.84571
#
# Epoch 336: val_accuracy did not improve from 0.84571
#
# Epoch 337: val_accuracy did not improve from 0.84571
#
# Epoch 338: val_accuracy did not improve from 0.84571
#
# Epoch 339: val_accuracy did not improve from 0.84571
#
# Epoch 340: val_accuracy did not improve from 0.84571
#
# Epoch 341: val_accuracy did not improve from 0.84571
#
# Epoch 342: val_accuracy did not improve from 0.84571
#
# Epoch 343: val_accuracy did not improve from 0.84571
#
# Epoch 344: val_accuracy did not improve from 0.84571
#
# Epoch 345: val_accuracy did not improve from 0.84571
#
# Epoch 346: val_accuracy did not improve from 0.84571
#
# Epoch 347: val_accuracy did not improve from 0.84571
#
# Epoch 348: val_accuracy did not improve from 0.84571
#
# Epoch 349: val_accuracy did not improve from 0.84571
#
# Epoch 350: val_accuracy did not improve from 0.84571
#
# Epoch 351: val_accuracy did not improve from 0.84571
#
# Epoch 352: val_accuracy did not improve from 0.84571
#
# Epoch 353: val_accuracy did not improve from 0.84571
#
# Epoch 354: val_accuracy did not improve from 0.84571
#
# Epoch 355: val_accuracy did not improve from 0.84571
#
# Epoch 356: val_accuracy did not improve from 0.84571
#
# Epoch 357: val_accuracy did not improve from 0.84571
#
# Epoch 358: val_accuracy did not improve from 0.84571
#
# Epoch 359: val_accuracy did not improve from 0.84571
#
# Epoch 360: val_accuracy did not improve from 0.84571
#
# Epoch 361: val_accuracy did not improve from 0.84571
#
# Epoch 362: val_accuracy did not improve from 0.84571
#
# Epoch 363: val_accuracy did not improve from 0.84571
#
# Epoch 364: val_accuracy did not improve from 0.84571
#
# Epoch 365: val_accuracy did not improve from 0.84571
#
# Epoch 366: val_accuracy did not improve from 0.84571
#
# Epoch 367: val_accuracy did not improve from 0.84571
#
# Epoch 368: val_accuracy did not improve from 0.84571
#
# Epoch 369: val_accuracy did not improve from 0.84571
#
# Epoch 370: val_accuracy did not improve from 0.84571
#
# Epoch 371: val_accuracy did not improve from 0.84571
#
# Epoch 372: val_accuracy did not improve from 0.84571
#
# Epoch 373: val_accuracy did not improve from 0.84571
#
# Epoch 374: val_accuracy did not improve from 0.84571
#
# Epoch 375: val_accuracy did not improve from 0.84571
#
# Epoch 376: val_accuracy did not improve from 0.84571
#
# Epoch 377: val_accuracy did not improve from 0.84571
#
# Epoch 378: val_accuracy did not improve from 0.84571
#
# Epoch 379: val_accuracy did not improve from 0.84571
#
# Epoch 380: val_accuracy did not improve from 0.84571
#
# Epoch 381: val_accuracy did not improve from 0.84571
#
# Epoch 382: val_accuracy did not improve from 0.84571
#
# Epoch 383: val_accuracy did not improve from 0.84571
#
# Epoch 384: val_accuracy did not improve from 0.84571
#
# Epoch 385: val_accuracy did not improve from 0.84571
#
# Epoch 386: val_accuracy did not improve from 0.84571
#
# Epoch 387: val_accuracy did not improve from 0.84571
#
# Epoch 388: val_accuracy did not improve from 0.84571
#
# Epoch 389: val_accuracy did not improve from 0.84571
#
# Epoch 390: val_accuracy did not improve from 0.84571
#
# Epoch 391: val_accuracy did not improve from 0.84571
#
# Epoch 392: val_accuracy did not improve from 0.84571
#
# Epoch 393: val_accuracy did not improve from 0.84571
#
# Epoch 394: val_accuracy did not improve from 0.84571
#
# Epoch 395: val_accuracy did not improve from 0.84571
#
# Epoch 396: val_accuracy did not improve from 0.84571
#
# Epoch 397: val_accuracy did not improve from 0.84571
#
# Epoch 398: val_accuracy did not improve from 0.84571
#
# Epoch 399: val_accuracy did not improve from 0.84571
#
# Epoch 400: val_accuracy did not improve from 0.84571
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1576 - accuracy: 0.8457
# 1:400 0.845714271068573
#
# Epoch 1: val_accuracy improved from -inf to 0.70286, saving model to /content/checkpts_1_800.hdf5
#
# Epoch 2: val_accuracy did not improve from 0.70286
#
# Epoch 3: val_accuracy did not improve from 0.70286
#
# Epoch 4: val_accuracy did not improve from 0.70286
#
# Epoch 5: val_accuracy did not improve from 0.70286
#
# Epoch 6: val_accuracy did not improve from 0.70286
#
# Epoch 7: val_accuracy did not improve from 0.70286
#
# Epoch 8: val_accuracy did not improve from 0.70286
#
# Epoch 9: val_accuracy did not improve from 0.70286
#
# Epoch 10: val_accuracy improved from 0.70286 to 0.70857, saving model to /content/checkpts_1_800.hdf5
#
# Epoch 11: val_accuracy did not improve from 0.70857
#
# Epoch 12: val_accuracy improved from 0.70857 to 0.71429, saving model to /content/checkpts_1_800.hdf5
#
# Epoch 13: val_accuracy did not improve from 0.71429
#
# Epoch 14: val_accuracy improved from 0.71429 to 0.73143, saving model to /content/checkpts_1_800.hdf5
#
# Epoch 15: val_accuracy did not improve from 0.73143
#
# Epoch 16: val_accuracy did not improve from 0.73143
#
# Epoch 17: val_accuracy did not improve from 0.73143
#
# Epoch 18: val_accuracy did not improve from 0.73143
#
# Epoch 19: val_accuracy improved from 0.73143 to 0.74286, saving model to /content/checkpts_1_800.hdf5
#
# Epoch 20: val_accuracy did not improve from 0.74286
#
# Epoch 21: val_accuracy improved from 0.74286 to 0.76000, saving model to /content/checkpts_1_800.hdf5
#
# Epoch 22: val_accuracy improved from 0.76000 to 0.78286, saving model to /content/checkpts_1_800.hdf5
#
# Epoch 23: val_accuracy did not improve from 0.78286
#
# Epoch 24: val_accuracy did not improve from 0.78286
#
# Epoch 25: val_accuracy did not improve from 0.78286
#
# Epoch 26: val_accuracy improved from 0.78286 to 0.81714, saving model to /content/checkpts_1_800.hdf5
#
# Epoch 27: val_accuracy did not improve from 0.81714
#
# Epoch 28: val_accuracy did not improve from 0.81714
#
# Epoch 29: val_accuracy did not improve from 0.81714
#
# Epoch 30: val_accuracy did not improve from 0.81714
#
# Epoch 31: val_accuracy improved from 0.81714 to 0.82286, saving model to /content/checkpts_1_800.hdf5
#
# Epoch 32: val_accuracy did not improve from 0.82286
#
# Epoch 33: val_accuracy did not improve from 0.82286
#
# Epoch 34: val_accuracy did not improve from 0.82286
#
# Epoch 35: val_accuracy did not improve from 0.82286
#
# Epoch 36: val_accuracy improved from 0.82286 to 0.84000, saving model to /content/checkpts_1_800.hdf5
#
# Epoch 37: val_accuracy did not improve from 0.84000
#
# Epoch 38: val_accuracy did not improve from 0.84000
#
# Epoch 39: val_accuracy did not improve from 0.84000
#
# Epoch 40: val_accuracy did not improve from 0.84000
#
# Epoch 41: val_accuracy did not improve from 0.84000
#
# Epoch 42: val_accuracy did not improve from 0.84000
#
# Epoch 43: val_accuracy did not improve from 0.84000
#
# Epoch 44: val_accuracy did not improve from 0.84000
#
# Epoch 45: val_accuracy did not improve from 0.84000
#
# Epoch 46: val_accuracy did not improve from 0.84000
#
# Epoch 47: val_accuracy did not improve from 0.84000
#
# Epoch 48: val_accuracy did not improve from 0.84000
#
# Epoch 49: val_accuracy did not improve from 0.84000
#
# Epoch 50: val_accuracy improved from 0.84000 to 0.84571, saving model to /content/checkpts_1_800.hdf5
#
# Epoch 51: val_accuracy did not improve from 0.84571
#
# Epoch 52: val_accuracy did not improve from 0.84571
#
# Epoch 53: val_accuracy did not improve from 0.84571
#
# Epoch 54: val_accuracy did not improve from 0.84571
#
# Epoch 55: val_accuracy did not improve from 0.84571
#
# Epoch 56: val_accuracy did not improve from 0.84571
#
# Epoch 57: val_accuracy did not improve from 0.84571
#
# Epoch 58: val_accuracy did not improve from 0.84571
#
# Epoch 59: val_accuracy did not improve from 0.84571
#
# Epoch 60: val_accuracy did not improve from 0.84571
#
# Epoch 61: val_accuracy did not improve from 0.84571
#
# Epoch 62: val_accuracy did not improve from 0.84571
#
# Epoch 63: val_accuracy did not improve from 0.84571
#
# Epoch 64: val_accuracy did not improve from 0.84571
#
# Epoch 65: val_accuracy did not improve from 0.84571
#
# Epoch 66: val_accuracy did not improve from 0.84571
#
# Epoch 67: val_accuracy did not improve from 0.84571
#
# Epoch 68: val_accuracy did not improve from 0.84571
#
# Epoch 69: val_accuracy did not improve from 0.84571
#
# Epoch 70: val_accuracy did not improve from 0.84571
#
# Epoch 71: val_accuracy did not improve from 0.84571
#
# Epoch 72: val_accuracy did not improve from 0.84571
#
# Epoch 73: val_accuracy did not improve from 0.84571
#
# Epoch 74: val_accuracy did not improve from 0.84571
#
# Epoch 75: val_accuracy did not improve from 0.84571
#
# Epoch 76: val_accuracy did not improve from 0.84571
#
# Epoch 77: val_accuracy did not improve from 0.84571
#
# Epoch 78: val_accuracy did not improve from 0.84571
#
# Epoch 79: val_accuracy did not improve from 0.84571
#
# Epoch 80: val_accuracy did not improve from 0.84571
#
# Epoch 81: val_accuracy did not improve from 0.84571
#
# Epoch 82: val_accuracy did not improve from 0.84571
#
# Epoch 83: val_accuracy did not improve from 0.84571
#
# Epoch 84: val_accuracy did not improve from 0.84571
#
# Epoch 85: val_accuracy did not improve from 0.84571
#
# Epoch 86: val_accuracy did not improve from 0.84571
#
# Epoch 87: val_accuracy did not improve from 0.84571
#
# Epoch 88: val_accuracy did not improve from 0.84571
#
# Epoch 89: val_accuracy did not improve from 0.84571
#
# Epoch 90: val_accuracy did not improve from 0.84571
#
# Epoch 91: val_accuracy did not improve from 0.84571
#
# Epoch 92: val_accuracy did not improve from 0.84571
#
# Epoch 93: val_accuracy did not improve from 0.84571
#
# Epoch 94: val_accuracy did not improve from 0.84571
#
# Epoch 95: val_accuracy did not improve from 0.84571
#
# Epoch 96: val_accuracy did not improve from 0.84571
#
# Epoch 97: val_accuracy did not improve from 0.84571
#
# Epoch 98: val_accuracy did not improve from 0.84571
#
# Epoch 99: val_accuracy did not improve from 0.84571
#
# Epoch 100: val_accuracy did not improve from 0.84571
#
# Epoch 101: val_accuracy did not improve from 0.84571
#
# Epoch 102: val_accuracy did not improve from 0.84571
#
# Epoch 103: val_accuracy did not improve from 0.84571
#
# Epoch 104: val_accuracy did not improve from 0.84571
#
# Epoch 105: val_accuracy did not improve from 0.84571
#
# Epoch 106: val_accuracy did not improve from 0.84571
#
# Epoch 107: val_accuracy did not improve from 0.84571
#
# Epoch 108: val_accuracy did not improve from 0.84571
#
# Epoch 109: val_accuracy did not improve from 0.84571
#
# Epoch 110: val_accuracy did not improve from 0.84571
#
# Epoch 111: val_accuracy did not improve from 0.84571
#
# Epoch 112: val_accuracy did not improve from 0.84571
#
# Epoch 113: val_accuracy did not improve from 0.84571
#
# Epoch 114: val_accuracy did not improve from 0.84571
#
# Epoch 115: val_accuracy did not improve from 0.84571
#
# Epoch 116: val_accuracy did not improve from 0.84571
#
# Epoch 117: val_accuracy did not improve from 0.84571
#
# Epoch 118: val_accuracy did not improve from 0.84571
#
# Epoch 119: val_accuracy did not improve from 0.84571
#
# Epoch 120: val_accuracy did not improve from 0.84571
#
# Epoch 121: val_accuracy did not improve from 0.84571
#
# Epoch 122: val_accuracy did not improve from 0.84571
#
# Epoch 123: val_accuracy did not improve from 0.84571
#
# Epoch 124: val_accuracy did not improve from 0.84571
#
# Epoch 125: val_accuracy did not improve from 0.84571
#
# Epoch 126: val_accuracy did not improve from 0.84571
#
# Epoch 127: val_accuracy did not improve from 0.84571
#
# Epoch 128: val_accuracy did not improve from 0.84571
#
# Epoch 129: val_accuracy did not improve from 0.84571
#
# Epoch 130: val_accuracy did not improve from 0.84571
#
# Epoch 131: val_accuracy did not improve from 0.84571
#
# Epoch 132: val_accuracy did not improve from 0.84571
#
# Epoch 133: val_accuracy did not improve from 0.84571
#
# Epoch 134: val_accuracy did not improve from 0.84571
#
# Epoch 135: val_accuracy did not improve from 0.84571
#
# Epoch 136: val_accuracy did not improve from 0.84571
#
# Epoch 137: val_accuracy did not improve from 0.84571
#
# Epoch 138: val_accuracy did not improve from 0.84571
#
# Epoch 139: val_accuracy did not improve from 0.84571
#
# Epoch 140: val_accuracy did not improve from 0.84571
#
# Epoch 141: val_accuracy did not improve from 0.84571
#
# Epoch 142: val_accuracy did not improve from 0.84571
#
# Epoch 143: val_accuracy did not improve from 0.84571
#
# Epoch 144: val_accuracy did not improve from 0.84571
#
# Epoch 145: val_accuracy did not improve from 0.84571
#
# Epoch 146: val_accuracy did not improve from 0.84571
#
# Epoch 147: val_accuracy did not improve from 0.84571
#
# Epoch 148: val_accuracy did not improve from 0.84571
#
# Epoch 149: val_accuracy did not improve from 0.84571
#
# Epoch 150: val_accuracy did not improve from 0.84571
#
# Epoch 151: val_accuracy did not improve from 0.84571
#
# Epoch 152: val_accuracy did not improve from 0.84571
#
# Epoch 153: val_accuracy did not improve from 0.84571
#
# Epoch 154: val_accuracy did not improve from 0.84571
#
# Epoch 155: val_accuracy did not improve from 0.84571
#
# Epoch 156: val_accuracy did not improve from 0.84571
#
# Epoch 157: val_accuracy did not improve from 0.84571
#
# Epoch 158: val_accuracy did not improve from 0.84571
#
# Epoch 159: val_accuracy did not improve from 0.84571
#
# Epoch 160: val_accuracy did not improve from 0.84571
#
# Epoch 161: val_accuracy did not improve from 0.84571
#
# Epoch 162: val_accuracy did not improve from 0.84571
#
# Epoch 163: val_accuracy did not improve from 0.84571
#
# Epoch 164: val_accuracy did not improve from 0.84571
#
# Epoch 165: val_accuracy did not improve from 0.84571
#
# Epoch 166: val_accuracy did not improve from 0.84571
#
# Epoch 167: val_accuracy did not improve from 0.84571
#
# Epoch 168: val_accuracy did not improve from 0.84571
#
# Epoch 169: val_accuracy did not improve from 0.84571
#
# Epoch 170: val_accuracy did not improve from 0.84571
#
# Epoch 171: val_accuracy did not improve from 0.84571
#
# Epoch 172: val_accuracy did not improve from 0.84571
#
# Epoch 173: val_accuracy did not improve from 0.84571
#
# Epoch 174: val_accuracy did not improve from 0.84571
#
# Epoch 175: val_accuracy did not improve from 0.84571
#
# Epoch 176: val_accuracy did not improve from 0.84571
#
# Epoch 177: val_accuracy did not improve from 0.84571
#
# Epoch 178: val_accuracy did not improve from 0.84571
#
# Epoch 179: val_accuracy did not improve from 0.84571
#
# Epoch 180: val_accuracy did not improve from 0.84571
#
# Epoch 181: val_accuracy did not improve from 0.84571
#
# Epoch 182: val_accuracy did not improve from 0.84571
#
# Epoch 183: val_accuracy did not improve from 0.84571
#
# Epoch 184: val_accuracy did not improve from 0.84571
#
# Epoch 185: val_accuracy did not improve from 0.84571
#
# Epoch 186: val_accuracy did not improve from 0.84571
#
# Epoch 187: val_accuracy did not improve from 0.84571
#
# Epoch 188: val_accuracy did not improve from 0.84571
#
# Epoch 189: val_accuracy did not improve from 0.84571
#
# Epoch 190: val_accuracy did not improve from 0.84571
#
# Epoch 191: val_accuracy did not improve from 0.84571
#
# Epoch 192: val_accuracy did not improve from 0.84571
#
# Epoch 193: val_accuracy did not improve from 0.84571
#
# Epoch 194: val_accuracy did not improve from 0.84571
#
# Epoch 195: val_accuracy did not improve from 0.84571
#
# Epoch 196: val_accuracy did not improve from 0.84571
#
# Epoch 197: val_accuracy did not improve from 0.84571
#
# Epoch 198: val_accuracy did not improve from 0.84571
#
# Epoch 199: val_accuracy did not improve from 0.84571
#
# Epoch 200: val_accuracy did not improve from 0.84571
#
# Epoch 201: val_accuracy did not improve from 0.84571
#
# Epoch 202: val_accuracy did not improve from 0.84571
#
# Epoch 203: val_accuracy did not improve from 0.84571
#
# Epoch 204: val_accuracy did not improve from 0.84571
#
# Epoch 205: val_accuracy did not improve from 0.84571
#
# Epoch 206: val_accuracy did not improve from 0.84571
#
# Epoch 207: val_accuracy did not improve from 0.84571
#
# Epoch 208: val_accuracy did not improve from 0.84571
#
# Epoch 209: val_accuracy did not improve from 0.84571
#
# Epoch 210: val_accuracy did not improve from 0.84571
#
# Epoch 211: val_accuracy did not improve from 0.84571
#
# Epoch 212: val_accuracy did not improve from 0.84571
#
# Epoch 213: val_accuracy did not improve from 0.84571
#
# Epoch 214: val_accuracy did not improve from 0.84571
#
# Epoch 215: val_accuracy did not improve from 0.84571
#
# Epoch 216: val_accuracy did not improve from 0.84571
#
# Epoch 217: val_accuracy did not improve from 0.84571
#
# Epoch 218: val_accuracy did not improve from 0.84571
#
# Epoch 219: val_accuracy did not improve from 0.84571
#
# Epoch 220: val_accuracy did not improve from 0.84571
#
# Epoch 221: val_accuracy did not improve from 0.84571
#
# Epoch 222: val_accuracy did not improve from 0.84571
#
# Epoch 223: val_accuracy did not improve from 0.84571
#
# Epoch 224: val_accuracy did not improve from 0.84571
#
# Epoch 225: val_accuracy did not improve from 0.84571
#
# Epoch 226: val_accuracy did not improve from 0.84571
#
# Epoch 227: val_accuracy did not improve from 0.84571
#
# Epoch 228: val_accuracy did not improve from 0.84571
#
# Epoch 229: val_accuracy did not improve from 0.84571
#
# Epoch 230: val_accuracy did not improve from 0.84571
#
# Epoch 231: val_accuracy did not improve from 0.84571
#
# Epoch 232: val_accuracy did not improve from 0.84571
#
# Epoch 233: val_accuracy did not improve from 0.84571
#
# Epoch 234: val_accuracy did not improve from 0.84571
#
# Epoch 235: val_accuracy did not improve from 0.84571
#
# Epoch 236: val_accuracy did not improve from 0.84571
#
# Epoch 237: val_accuracy did not improve from 0.84571
#
# Epoch 238: val_accuracy did not improve from 0.84571
#
# Epoch 239: val_accuracy did not improve from 0.84571
#
# Epoch 240: val_accuracy did not improve from 0.84571
#
# Epoch 241: val_accuracy did not improve from 0.84571
#
# Epoch 242: val_accuracy did not improve from 0.84571
#
# Epoch 243: val_accuracy did not improve from 0.84571
#
# Epoch 244: val_accuracy did not improve from 0.84571
#
# Epoch 245: val_accuracy did not improve from 0.84571
#
# Epoch 246: val_accuracy did not improve from 0.84571
#
# Epoch 247: val_accuracy did not improve from 0.84571
#
# Epoch 248: val_accuracy did not improve from 0.84571
#
# Epoch 249: val_accuracy did not improve from 0.84571
#
# Epoch 250: val_accuracy did not improve from 0.84571
#
# Epoch 251: val_accuracy did not improve from 0.84571
#
# Epoch 252: val_accuracy did not improve from 0.84571
#
# Epoch 253: val_accuracy did not improve from 0.84571
#
# Epoch 254: val_accuracy did not improve from 0.84571
#
# Epoch 255: val_accuracy did not improve from 0.84571
#
# Epoch 256: val_accuracy did not improve from 0.84571
#
# ...
#
# Epoch 507: val_accuracy did not improve from 0.84571
#
# Epoch 508: val_accuracy did not improve from 0.84571
#
# Epoch 509: val_accuracy did not improve from 0.84571
#
# Epoch 510: val_accuracy did not improve from 0.84571
#
# Epoch 511: val_accuracy did not improve from 0.84571
#
# Epoch 512: val_accuracy did not improve from 0.84571
#
# Epoch 513: val_accuracy did not improve from 0.84571
#
# Epoch 514: val_accuracy did not improve from 0.84571
#
# Epoch 515: val_accuracy did not improve from 0.84571
#
# Epoch 516: val_accuracy did not improve from 0.84571
#
# Epoch 517: val_accuracy did not improve from 0.84571
#
# Epoch 518: val_accuracy did not improve from 0.84571
#
# Epoch 519: val_accuracy did not improve from 0.84571
#
# Epoch 520: val_accuracy did not improve from 0.84571
#
# Epoch 521: val_accuracy did not improve from 0.84571
#
# Epoch 522: val_accuracy did not improve from 0.84571
#
# Epoch 523: val_accuracy did not improve from 0.84571
#
# Epoch 524: val_accuracy did not improve from 0.84571
#
# Epoch 525: val_accuracy did not improve from 0.84571
#
# Epoch 526: val_accuracy did not improve from 0.84571
#
# Epoch 527: val_accuracy did not improve from 0.84571
#
# Epoch 528: val_accuracy did not improve from 0.84571
#
# Epoch 529: val_accuracy did not improve from 0.84571
#
# Epoch 530: val_accuracy did not improve from 0.84571
#
# Epoch 531: val_accuracy did not improve from 0.84571
#
# Epoch 532: val_accuracy did not improve from 0.84571
#
# Epoch 533: val_accuracy did not improve from 0.84571
#
# Epoch 534: val_accuracy did not improve from 0.84571
#
# Epoch 535: val_accuracy did not improve from 0.84571
#
# Epoch 536: val_accuracy did not improve from 0.84571
#
# Epoch 537: val_accuracy did not improve from 0.84571
#
# Epoch 538: val_accuracy did not improve from 0.84571
#
# Epoch 539: val_accuracy did not improve from 0.84571
#
# Epoch 540: val_accuracy did not improve from 0.84571
#
# Epoch 541: val_accuracy did not improve from 0.84571
#
# Epoch 542: val_accuracy did not improve from 0.84571
#
# Epoch 543: val_accuracy did not improve from 0.84571
#
# Epoch 544: val_accuracy did not improve from 0.84571
#
# Epoch 545: val_accuracy did not improve from 0.84571
#
# Epoch 546: val_accuracy did not improve from 0.84571
#
# Epoch 547: val_accuracy did not improve from 0.84571
#
# Epoch 548: val_accuracy did not improve from 0.84571
#
# Epoch 549: val_accuracy did not improve from 0.84571
#
# Epoch 550: val_accuracy did not improve from 0.84571
#
# Epoch 551: val_accuracy did not improve from 0.84571
#
# Epoch 552: val_accuracy did not improve from 0.84571
#
# Epoch 553: val_accuracy did not improve from 0.84571
#
# Epoch 554: val_accuracy did not improve from 0.84571
#
# Epoch 555: val_accuracy did not improve from 0.84571
#
# Epoch 556: val_accuracy did not improve from 0.84571
#
# Epoch 557: val_accuracy did not improve from 0.84571
#
# Epoch 558: val_accuracy did not improve from 0.84571
#
# Epoch 559: val_accuracy did not improve from 0.84571
#
# Epoch 560: val_accuracy did not improve from 0.84571
#
# Epoch 561: val_accuracy did not improve from 0.84571
#
# Epoch 562: val_accuracy did not improve from 0.84571
#
# Epoch 563: val_accuracy did not improve from 0.84571
#
# Epoch 564: val_accuracy did not improve from 0.84571
#
# Epoch 565: val_accuracy did not improve from 0.84571
#
# Epoch 566: val_accuracy did not improve from 0.84571
#
# Epoch 567: val_accuracy did not improve from 0.84571
#
# Epoch 568: val_accuracy did not improve from 0.84571
#
# Epoch 569: val_accuracy did not improve from 0.84571
#
# Epoch 570: val_accuracy did not improve from 0.84571
#
# Epoch 571: val_accuracy did not improve from 0.84571
#
# Epoch 572: val_accuracy did not improve from 0.84571
#
# Epoch 573: val_accuracy did not improve from 0.84571
#
# Epoch 574: val_accuracy did not improve from 0.84571
#
# Epoch 575: val_accuracy did not improve from 0.84571
#
# Epoch 576: val_accuracy did not improve from 0.84571
#
# Epoch 577: val_accuracy did not improve from 0.84571
#
# Epoch 578: val_accuracy did not improve from 0.84571
#
# Epoch 579: val_accuracy did not improve from 0.84571
#
# Epoch 580: val_accuracy did not improve from 0.84571
#
# Epoch 581: val_accuracy did not improve from 0.84571
#
# Epoch 582: val_accuracy did not improve from 0.84571
#
# Epoch 583: val_accuracy did not improve from 0.84571
#
# Epoch 584: val_accuracy did not improve from 0.84571
#
# Epoch 585: val_accuracy did not improve from 0.84571
#
# Epoch 586: val_accuracy did not improve from 0.84571
#
# Epoch 587: val_accuracy did not improve from 0.84571
#
# Epoch 588: val_accuracy did not improve from 0.84571
#
# Epoch 589: val_accuracy did not improve from 0.84571
#
# Epoch 590: val_accuracy did not improve from 0.84571
#
# Epoch 591: val_accuracy did not improve from 0.84571
#
# Epoch 592: val_accuracy did not improve from 0.84571
#
# Epoch 593: val_accuracy did not improve from 0.84571
#
# Epoch 594: val_accuracy did not improve from 0.84571
#
# Epoch 595: val_accuracy did not improve from 0.84571
#
# Epoch 596: val_accuracy did not improve from 0.84571
#
# Epoch 597: val_accuracy did not improve from 0.84571
#
# Epoch 598: val_accuracy did not improve from 0.84571
#
# Epoch 599: val_accuracy did not improve from 0.84571
#
# Epoch 600: val_accuracy did not improve from 0.84571
#
# Epoch 601: val_accuracy did not improve from 0.84571
#
# Epoch 602: val_accuracy did not improve from 0.84571
#
# Epoch 603: val_accuracy did not improve from 0.84571
#
# Epoch 604: val_accuracy did not improve from 0.84571
#
# Epoch 605: val_accuracy did not improve from 0.84571
#
# Epoch 606: val_accuracy did not improve from 0.84571
#
# Epoch 607: val_accuracy did not improve from 0.84571
#
# Epoch 608: val_accuracy did not improve from 0.84571
#
# Epoch 609: val_accuracy did not improve from 0.84571
#
# Epoch 610: val_accuracy did not improve from 0.84571
#
# Epoch 611: val_accuracy did not improve from 0.84571
#
# Epoch 612: val_accuracy did not improve from 0.84571
#
# Epoch 613: val_accuracy did not improve from 0.84571
#
# Epoch 614: val_accuracy did not improve from 0.84571
#
# Epoch 615: val_accuracy did not improve from 0.84571
#
# Epoch 616: val_accuracy did not improve from 0.84571
#
# Epoch 617: val_accuracy did not improve from 0.84571
#
# Epoch 618: val_accuracy did not improve from 0.84571
#
# Epoch 619: val_accuracy did not improve from 0.84571
#
# Epoch 620: val_accuracy did not improve from 0.84571
#
# Epoch 621: val_accuracy did not improve from 0.84571
#
# Epoch 622: val_accuracy did not improve from 0.84571
#
# Epoch 623: val_accuracy did not improve from 0.84571
#
# Epoch 624: val_accuracy did not improve from 0.84571
#
# Epoch 625: val_accuracy did not improve from 0.84571
#
# Epoch 626: val_accuracy did not improve from 0.84571
#
# Epoch 627: val_accuracy did not improve from 0.84571
#
# Epoch 628: val_accuracy did not improve from 0.84571
#
# Epoch 629: val_accuracy did not improve from 0.84571
#
# Epoch 630: val_accuracy did not improve from 0.84571
#
# Epoch 631: val_accuracy did not improve from 0.84571
#
# Epoch 632: val_accuracy did not improve from 0.84571
#
# Epoch 633: val_accuracy did not improve from 0.84571
#
# Epoch 634: val_accuracy did not improve from 0.84571
#
# Epoch 635: val_accuracy did not improve from 0.84571
#
# Epoch 636: val_accuracy did not improve from 0.84571
#
# Epoch 637: val_accuracy did not improve from 0.84571
#
# Epoch 638: val_accuracy did not improve from 0.84571
#
# Epoch 639: val_accuracy did not improve from 0.84571
#
# Epoch 640: val_accuracy did not improve from 0.84571
#
# Epoch 641: val_accuracy did not improve from 0.84571
#
# Epoch 642: val_accuracy did not improve from 0.84571
#
# Epoch 643: val_accuracy did not improve from 0.84571
#
# Epoch 644: val_accuracy did not improve from 0.84571
#
# Epoch 645: val_accuracy did not improve from 0.84571
#
# Epoch 646: val_accuracy did not improve from 0.84571
#
# Epoch 647: val_accuracy did not improve from 0.84571
#
# Epoch 648: val_accuracy did not improve from 0.84571
#
# Epoch 649: val_accuracy did not improve from 0.84571
#
# Epoch 650: val_accuracy did not improve from 0.84571
#
# Epoch 651: val_accuracy did not improve from 0.84571
#
# Epoch 652: val_accuracy did not improve from 0.84571
#
# Epoch 653: val_accuracy did not improve from 0.84571
#
# Epoch 654: val_accuracy did not improve from 0.84571
#
# Epoch 655: val_accuracy did not improve from 0.84571
#
# Epoch 656: val_accuracy did not improve from 0.84571
#
# Epoch 657: val_accuracy did not improve from 0.84571
#
# Epoch 658: val_accuracy did not improve from 0.84571
#
# Epoch 659: val_accuracy did not improve from 0.84571
#
# Epoch 660: val_accuracy did not improve from 0.84571
#
# Epoch 661: val_accuracy did not improve from 0.84571
#
# Epoch 662: val_accuracy did not improve from 0.84571
#
# Epoch 663: val_accuracy did not improve from 0.84571
#
# Epoch 664: val_accuracy did not improve from 0.84571
#
# Epoch 665: val_accuracy did not improve from 0.84571
#
# Epoch 666: val_accuracy did not improve from 0.84571
#
# Epoch 667: val_accuracy did not improve from 0.84571
#
# Epoch 668: val_accuracy did not improve from 0.84571
#
# Epoch 669: val_accuracy did not improve from 0.84571
#
# Epoch 670: val_accuracy did not improve from 0.84571
#
# Epoch 671: val_accuracy did not improve from 0.84571
#
# Epoch 672: val_accuracy did not improve from 0.84571
#
# Epoch 673: val_accuracy did not improve from 0.84571
#
# Epoch 674: val_accuracy did not improve from 0.84571
#
# Epoch 675: val_accuracy did not improve from 0.84571
#
# Epoch 676: val_accuracy did not improve from 0.84571
#
# Epoch 677: val_accuracy did not improve from 0.84571
#
# Epoch 678: val_accuracy did not improve from 0.84571
#
# Epoch 679: val_accuracy did not improve from 0.84571
#
# Epoch 680: val_accuracy did not improve from 0.84571
#
# Epoch 681: val_accuracy did not improve from 0.84571
#
# Epoch 682: val_accuracy did not improve from 0.84571
#
# Epoch 683: val_accuracy did not improve from 0.84571
#
# Epoch 684: val_accuracy did not improve from 0.84571
#
# Epoch 685: val_accuracy did not improve from 0.84571
#
# Epoch 686: val_accuracy did not improve from 0.84571
#
# Epoch 687: val_accuracy did not improve from 0.84571
#
# Epoch 688: val_accuracy did not improve from 0.84571
#
# Epoch 689: val_accuracy did not improve from 0.84571
#
# Epoch 690: val_accuracy did not improve from 0.84571
#
# Epoch 691: val_accuracy did not improve from 0.84571
#
# Epoch 692: val_accuracy did not improve from 0.84571
#
# Epoch 693: val_accuracy did not improve from 0.84571
#
# Epoch 694: val_accuracy did not improve from 0.84571
#
# Epoch 695: val_accuracy did not improve from 0.84571
#
# Epoch 696: val_accuracy did not improve from 0.84571
#
# Epoch 697: val_accuracy did not improve from 0.84571
#
# Epoch 698: val_accuracy did not improve from 0.84571
#
# Epoch 699: val_accuracy did not improve from 0.84571
#
# Epoch 700: val_accuracy did not improve from 0.84571
#
# Epoch 701: val_accuracy did not improve from 0.84571
#
# Epoch 702: val_accuracy did not improve from 0.84571
#
# Epoch 703: val_accuracy did not improve from 0.84571
#
# Epoch 704: val_accuracy did not improve from 0.84571
#
# Epoch 705: val_accuracy did not improve from 0.84571
#
# Epoch 706: val_accuracy did not improve from 0.84571
#
# Epoch 707: val_accuracy did not improve from 0.84571
#
# Epoch 708: val_accuracy did not improve from 0.84571
#
# Epoch 709: val_accuracy did not improve from 0.84571
#
# Epoch 710: val_accuracy did not improve from 0.84571
#
# Epoch 711: val_accuracy did not improve from 0.84571
#
# Epoch 712: val_accuracy did not improve from 0.84571
#
# Epoch 713: val_accuracy did not improve from 0.84571
#
# Epoch 714: val_accuracy did not improve from 0.84571
#
# Epoch 715: val_accuracy did not improve from 0.84571
#
# Epoch 716: val_accuracy did not improve from 0.84571
#
# Epoch 717: val_accuracy did not improve from 0.84571
#
# Epoch 718: val_accuracy did not improve from 0.84571
#
# Epoch 719: val_accuracy did not improve from 0.84571
#
# Epoch 720: val_accuracy did not improve from 0.84571
#
# Epoch 721: val_accuracy did not improve from 0.84571
#
# Epoch 722: val_accuracy did not improve from 0.84571
#
# Epoch 723: val_accuracy did not improve from 0.84571
#
# Epoch 724: val_accuracy did not improve from 0.84571
#
# Epoch 725: val_accuracy did not improve from 0.84571
#
# Epoch 726: val_accuracy did not improve from 0.84571
#
# Epoch 727: val_accuracy did not improve from 0.84571
#
# Epoch 728: val_accuracy did not improve from 0.84571
#
# Epoch 729: val_accuracy did not improve from 0.84571
#
# Epoch 730: val_accuracy did not improve from 0.84571
#
# Epoch 731: val_accuracy did not improve from 0.84571
#
# Epoch 732: val_accuracy did not improve from 0.84571
#
# Epoch 733: val_accuracy did not improve from 0.84571
#
# Epoch 734: val_accuracy did not improve from 0.84571
#
# Epoch 735: val_accuracy did not improve from 0.84571
#
# Epoch 736: val_accuracy did not improve from 0.84571
#
# Epoch 737: val_accuracy did not improve from 0.84571
#
# Epoch 738: val_accuracy did not improve from 0.84571
#
# Epoch 739: val_accuracy did not improve from 0.84571
#
# Epoch 740: val_accuracy did not improve from 0.84571
#
# Epoch 741: val_accuracy did not improve from 0.84571
#
# Epoch 742: val_accuracy did not improve from 0.84571
#
# Epoch 743: val_accuracy did not improve from 0.84571
#
# Epoch 744: val_accuracy did not improve from 0.84571
#
# Epoch 745: val_accuracy did not improve from 0.84571
#
# Epoch 746: val_accuracy did not improve from 0.84571
#
# Epoch 747: val_accuracy did not improve from 0.84571
#
# Epoch 748: val_accuracy did not improve from 0.84571
#
# Epoch 749: val_accuracy did not improve from 0.84571
#
# Epoch 750: val_accuracy did not improve from 0.84571
#
# Epoch 751: val_accuracy did not improve from 0.84571
#
# Epoch 752: val_accuracy did not improve from 0.84571
#
# Epoch 753: val_accuracy did not improve from 0.84571
#
# Epoch 754: val_accuracy did not improve from 0.84571
#
# Epoch 755: val_accuracy did not improve from 0.84571
#
# Epoch 756: val_accuracy did not improve from 0.84571
#
# Epoch 757: val_accuracy did not improve from 0.84571
#
# Epoch 758: val_accuracy did not improve from 0.84571
#
# Epoch 759: val_accuracy did not improve from 0.84571
#
# Epoch 760: val_accuracy did not improve from 0.84571
#
# Epoch 761: val_accuracy did not improve from 0.84571
#
# Epoch 762: val_accuracy did not improve from 0.84571
#
# Epoch 763: val_accuracy did not improve from 0.84571
#
# Epoch 764: val_accuracy did not improve from 0.84571
#
# Epoch 765: val_accuracy did not improve from 0.84571
#
# Epoch 766: val_accuracy did not improve from 0.84571
#
# Epoch 767: val_accuracy did not improve from 0.84571
#
# Epoch 768: val_accuracy did not improve from 0.84571
#
# Epoch 769: val_accuracy did not improve from 0.84571
#
# Epoch 770: val_accuracy did not improve from 0.84571
#
# Epoch 771: val_accuracy did not improve from 0.84571
#
# Epoch 772: val_accuracy did not improve from 0.84571
#
# Epoch 773: val_accuracy did not improve from 0.84571
#
# Epoch 774: val_accuracy did not improve from 0.84571
#
# Epoch 775: val_accuracy did not improve from 0.84571
#
# Epoch 776: val_accuracy did not improve from 0.84571
#
# Epoch 777: val_accuracy did not improve from 0.84571
#
# Epoch 778: val_accuracy did not improve from 0.84571
#
# Epoch 779: val_accuracy did not improve from 0.84571
#
# Epoch 780: val_accuracy did not improve from 0.84571
#
# Epoch 781: val_accuracy did not improve from 0.84571
#
# Epoch 782: val_accuracy did not improve from 0.84571
#
# Epoch 783: val_accuracy did not improve from 0.84571
#
# Epoch 784: val_accuracy did not improve from 0.84571
#
# Epoch 785: val_accuracy did not improve from 0.84571
#
# Epoch 786: val_accuracy did not improve from 0.84571
#
# Epoch 787: val_accuracy did not improve from 0.84571
#
# Epoch 788: val_accuracy did not improve from 0.84571
#
# Epoch 789: val_accuracy did not improve from 0.84571
#
# Epoch 790: val_accuracy did not improve from 0.84571
#
# Epoch 791: val_accuracy did not improve from 0.84571
#
# Epoch 792: val_accuracy did not improve from 0.84571
#
# Epoch 793: val_accuracy did not improve from 0.84571
#
# Epoch 794: val_accuracy did not improve from 0.84571
#
# Epoch 795: val_accuracy did not improve from 0.84571
#
# Epoch 796: val_accuracy did not improve from 0.84571
#
# Epoch 797: val_accuracy did not improve from 0.84571
#
# Epoch 798: val_accuracy did not improve from 0.84571
#
# Epoch 799: val_accuracy did not improve from 0.84571
#
# Epoch 800: val_accuracy did not improve from 0.84571
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1309 - accuracy: 0.8457
# 1:800 0.845714271068573

# %%
from tensorflow.keras.optimizers import SGD

opt = SGD(lr=0.01, momentum=0.9)

model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(5, input_shape=(5, )))
model.add(tf.keras.layers.Dense(26, activation="relu"))
model.add(tf.keras.layers.Dense(5, activation="relu"))
model.add(tf.keras.layers.Dense(1, activation="sigmoid"))
model.compile(optimizer=opt, metrics='accuracy', loss='mse')

checkpoint = ModelCheckpoint('/content/checkpts_2_200.hdf5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

model.fit(x_train, y_train, batch_size=15, epochs=200, verbose=0, validation_data=(x_test, y_test), callbacks=callbacks_list)
model.load_weights("checkpts_2_200.hdf5")
_, acc = model.evaluate(x_test, y_test)
print('2:200 '+str(acc))

model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(5, input_shape=(5, )))
model.add(tf.keras.layers.Dense(26, activation="relu"))
model.add(tf.keras.layers.Dense(5, activation="relu"))
model.add(tf.keras.layers.Dense(1, activation="sigmoid"))
model.compile(optimizer=opt, metrics='accuracy', loss='mse')

checkpoint = ModelCheckpoint('/content/checkpts_2_400.hdf5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

model.fit(x_train, y_train, batch_size=15, epochs=400, verbose=0, validation_data=(x_test, y_test), callbacks=callbacks_list)
model.load_weights("checkpts_2_400.hdf5")
_, acc = model.evaluate(x_test, y_test)
print('2:400 '+str(acc))

model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(5, input_shape=(5, )))
model.add(tf.keras.layers.Dense(26, activation="relu"))
model.add(tf.keras.layers.Dense(5, activation="relu"))
model.add(tf.keras.layers.Dense(1, activation="sigmoid"))
model.compile(optimizer=opt, metrics='accuracy', loss='mse')

checkpoint = ModelCheckpoint('/content/checkpts_2_800.hdf5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

model.fit(x_train, y_train, batch_size=15, epochs=800, verbose=0, validation_data=(x_test, y_test), callbacks=callbacks_list)
model.load_weights("checkpts_2_800.hdf5")
_, acc = model.evaluate(x_test, y_test)
print('2:800 '+str(acc))
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# Epoch 1: val_accuracy improved from -inf to 0.70286, saving model to /content/checkpts_2_200.hdf5
#
# Epoch 2: val_accuracy did not improve from 0.70286
#
# Epoch 3: val_accuracy did not improve from 0.70286
#
# Epoch 4: val_accuracy did not improve from 0.70286
#
# Epoch 5: val_accuracy did not improve from 0.70286
#
# Epoch 6: val_accuracy did not improve from 0.70286
#
# Epoch 7: val_accuracy did not improve from 0.70286
#
# Epoch 8: val_accuracy did not improve from 0.70286
#
# Epoch 9: val_accuracy did not improve from 0.70286
#
# Epoch 10: val_accuracy did not improve from 0.70286
#
# Epoch 11: val_accuracy did not improve from 0.70286
#
# Epoch 12: val_accuracy did not improve from 0.70286
#
# Epoch 13: val_accuracy did not improve from 0.70286
#
# Epoch 14: val_accuracy did not improve from 0.70286
#
# Epoch 15: val_accuracy improved from 0.70286 to 0.71429, saving model to /content/checkpts_2_200.hdf5
#
# Epoch 16: val_accuracy improved from 0.71429 to 0.72571, saving model to /content/checkpts_2_200.hdf5
#
# Epoch 17: val_accuracy improved from 0.72571 to 0.76571, saving model to /content/checkpts_2_200.hdf5
#
# Epoch 18: val_accuracy improved from 0.76571 to 0.77714, saving model to /content/checkpts_2_200.hdf5
#
# Epoch 19: val_accuracy improved from 0.77714 to 0.83429, saving model to /content/checkpts_2_200.hdf5
#
# Epoch 20: val_accuracy improved from 0.83429 to 0.84571, saving model to /content/checkpts_2_200.hdf5
#
# Epoch 21: val_accuracy did not improve from 0.84571
#
# Epoch 22: val_accuracy did not improve from 0.84571
#
# Epoch 23: val_accuracy did not improve from 0.84571
#
# Epoch 24: val_accuracy did not improve from 0.84571
#
# Epoch 25: val_accuracy did not improve from 0.84571
#
# Epoch 26: val_accuracy did not improve from 0.84571
#
# Epoch 27: val_accuracy did not improve from 0.84571
#
# Epoch 28: val_accuracy did not improve from 0.84571
#
# Epoch 29: val_accuracy did not improve from 0.84571
#
# Epoch 30: val_accuracy did not improve from 0.84571
#
# Epoch 31: val_accuracy did not improve from 0.84571
#
# Epoch 32: val_accuracy did not improve from 0.84571
#
# Epoch 33: val_accuracy did not improve from 0.84571
#
# Epoch 34: val_accuracy did not improve from 0.84571
#
# Epoch 35: val_accuracy did not improve from 0.84571
#
# Epoch 36: val_accuracy did not improve from 0.84571
#
# Epoch 37: val_accuracy did not improve from 0.84571
#
# Epoch 38: val_accuracy improved from 0.84571 to 0.85143, saving model to /content/checkpts_2_200.hdf5
#
# Epoch 39: val_accuracy did not improve from 0.85143
#
# Epoch 40: val_accuracy did not improve from 0.85143
#
# Epoch 41: val_accuracy did not improve from 0.85143
#
# Epoch 42: val_accuracy did not improve from 0.85143
#
# Epoch 43: val_accuracy did not improve from 0.85143
#
# Epoch 44: val_accuracy did not improve from 0.85143
#
# Epoch 45: val_accuracy did not improve from 0.85143
#
# Epoch 46: val_accuracy did not improve from 0.85143
#
# Epoch 47: val_accuracy did not improve from 0.85143
#
# Epoch 48: val_accuracy did not improve from 0.85143
#
# Epoch 49: val_accuracy did not improve from 0.85143
#
# Epoch 50: val_accuracy did not improve from 0.85143
#
# Epoch 51: val_accuracy did not improve from 0.85143
#
# Epoch 52: val_accuracy did not improve from 0.85143
#
# Epoch 53: val_accuracy did not improve from 0.85143
#
# Epoch 54: val_accuracy did not improve from 0.85143
#
# Epoch 55: val_accuracy did not improve from 0.85143
#
# Epoch 56: val_accuracy did not improve from 0.85143
#
# Epoch 57: val_accuracy did not improve from 0.85143
#
# Epoch 58: val_accuracy did not improve from 0.85143
#
# Epoch 59: val_accuracy did not improve from 0.85143
#
# Epoch 60: val_accuracy did not improve from 0.85143
#
# Epoch 61: val_accuracy did not improve from 0.85143
#
# Epoch 62: val_accuracy did not improve from 0.85143
#
# Epoch 63: val_accuracy did not improve from 0.85143
#
# Epoch 64: val_accuracy did not improve from 0.85143
#
# Epoch 65: val_accuracy did not improve from 0.85143
#
# Epoch 66: val_accuracy did not improve from 0.85143
#
# Epoch 67: val_accuracy did not improve from 0.85143
#
# Epoch 68: val_accuracy did not improve from 0.85143
#
# Epoch 69: val_accuracy did not improve from 0.85143
#
# Epoch 70: val_accuracy did not improve from 0.85143
#
# Epoch 71: val_accuracy did not improve from 0.85143
#
# Epoch 72: val_accuracy did not improve from 0.85143
#
# Epoch 73: val_accuracy did not improve from 0.85143
#
# Epoch 74: val_accuracy did not improve from 0.85143
#
# Epoch 75: val_accuracy did not improve from 0.85143
#
# Epoch 76: val_accuracy did not improve from 0.85143
#
# Epoch 77: val_accuracy did not improve from 0.85143
#
# Epoch 78: val_accuracy did not improve from 0.85143
#
# Epoch 79: val_accuracy did not improve from 0.85143
#
# Epoch 80: val_accuracy did not improve from 0.85143
#
# Epoch 81: val_accuracy did not improve from 0.85143
#
# Epoch 82: val_accuracy did not improve from 0.85143
#
# Epoch 83: val_accuracy did not improve from 0.85143
#
# Epoch 84: val_accuracy did not improve from 0.85143
#
# Epoch 85: val_accuracy did not improve from 0.85143
#
# Epoch 86: val_accuracy did not improve from 0.85143
#
# Epoch 87: val_accuracy did not improve from 0.85143
#
# Epoch 88: val_accuracy did not improve from 0.85143
#
# Epoch 89: val_accuracy did not improve from 0.85143
#
# Epoch 90: val_accuracy did not improve from 0.85143
#
# Epoch 91: val_accuracy did not improve from 0.85143
#
# Epoch 92: val_accuracy did not improve from 0.85143
#
# Epoch 93: val_accuracy did not improve from 0.85143
#
# Epoch 94: val_accuracy did not improve from 0.85143
#
# Epoch 95: val_accuracy did not improve from 0.85143
#
# Epoch 96: val_accuracy did not improve from 0.85143
#
# Epoch 97: val_accuracy did not improve from 0.85143
#
# Epoch 98: val_accuracy did not improve from 0.85143
#
# Epoch 99: val_accuracy did not improve from 0.85143
#
# Epoch 100: val_accuracy did not improve from 0.85143
#
# Epoch 101: val_accuracy did not improve from 0.85143
#
# Epoch 102: val_accuracy did not improve from 0.85143
#
# Epoch 103: val_accuracy did not improve from 0.85143
#
# Epoch 104: val_accuracy did not improve from 0.85143
#
# Epoch 105: val_accuracy did not improve from 0.85143
#
# Epoch 106: val_accuracy did not improve from 0.85143
#
# Epoch 107: val_accuracy did not improve from 0.85143
#
# Epoch 108: val_accuracy did not improve from 0.85143
#
# Epoch 109: val_accuracy did not improve from 0.85143
#
# Epoch 110: val_accuracy did not improve from 0.85143
#
# Epoch 111: val_accuracy did not improve from 0.85143
#
# Epoch 112: val_accuracy did not improve from 0.85143
#
# Epoch 113: val_accuracy did not improve from 0.85143
#
# Epoch 114: val_accuracy did not improve from 0.85143
#
# Epoch 115: val_accuracy did not improve from 0.85143
#
# Epoch 116: val_accuracy did not improve from 0.85143
#
# Epoch 117: val_accuracy did not improve from 0.85143
#
# Epoch 118: val_accuracy did not improve from 0.85143
#
# Epoch 119: val_accuracy did not improve from 0.85143
#
# Epoch 120: val_accuracy did not improve from 0.85143
#
# Epoch 121: val_accuracy did not improve from 0.85143
#
# Epoch 122: val_accuracy did not improve from 0.85143
#
# Epoch 123: val_accuracy did not improve from 0.85143
#
# Epoch 124: val_accuracy did not improve from 0.85143
#
# Epoch 125: val_accuracy did not improve from 0.85143
#
# Epoch 126: val_accuracy did not improve from 0.85143
#
# Epoch 127: val_accuracy did not improve from 0.85143
#
# Epoch 128: val_accuracy did not improve from 0.85143
#
# Epoch 129: val_accuracy did not improve from 0.85143
#
# Epoch 130: val_accuracy did not improve from 0.85143
#
# Epoch 131: val_accuracy did not improve from 0.85143
#
# Epoch 132: val_accuracy did not improve from 0.85143
#
# Epoch 133: val_accuracy did not improve from 0.85143
#
# Epoch 134: val_accuracy did not improve from 0.85143
#
# Epoch 135: val_accuracy did not improve from 0.85143
#
# Epoch 136: val_accuracy did not improve from 0.85143
#
# Epoch 137: val_accuracy did not improve from 0.85143
#
# Epoch 138: val_accuracy did not improve from 0.85143
#
# Epoch 139: val_accuracy did not improve from 0.85143
#
# Epoch 140: val_accuracy did not improve from 0.85143
#
# Epoch 141: val_accuracy did not improve from 0.85143
#
# Epoch 142: val_accuracy did not improve from 0.85143
#
# Epoch 143: val_accuracy did not improve from 0.85143
#
# Epoch 144: val_accuracy did not improve from 0.85143
#
# Epoch 145: val_accuracy did not improve from 0.85143
#
# Epoch 146: val_accuracy did not improve from 0.85143
#
# Epoch 147: val_accuracy did not improve from 0.85143
#
# Epoch 148: val_accuracy did not improve from 0.85143
#
# Epoch 149: val_accuracy did not improve from 0.85143
#
# Epoch 150: val_accuracy did not improve from 0.85143
#
# Epoch 151: val_accuracy did not improve from 0.85143
#
# Epoch 152: val_accuracy did not improve from 0.85143
#
# Epoch 153: val_accuracy did not improve from 0.85143
#
# Epoch 154: val_accuracy did not improve from 0.85143
#
# Epoch 155: val_accuracy did not improve from 0.85143
#
# Epoch 156: val_accuracy did not improve from 0.85143
#
# Epoch 157: val_accuracy did not improve from 0.85143
#
# Epoch 158: val_accuracy did not improve from 0.85143
#
# Epoch 159: val_accuracy did not improve from 0.85143
#
# Epoch 160: val_accuracy did not improve from 0.85143
#
# Epoch 161: val_accuracy did not improve from 0.85143
#
# Epoch 162: val_accuracy did not improve from 0.85143
#
# Epoch 163: val_accuracy did not improve from 0.85143
#
# Epoch 164: val_accuracy did not improve from 0.85143
#
# Epoch 165: val_accuracy did not improve from 0.85143
#
# Epoch 166: val_accuracy did not improve from 0.85143
#
# Epoch 167: val_accuracy did not improve from 0.85143
#
# Epoch 168: val_accuracy did not improve from 0.85143
#
# Epoch 169: val_accuracy did not improve from 0.85143
#
# Epoch 170: val_accuracy did not improve from 0.85143
#
# Epoch 171: val_accuracy did not improve from 0.85143
#
# Epoch 172: val_accuracy did not improve from 0.85143
#
# Epoch 173: val_accuracy did not improve from 0.85143
#
# Epoch 174: val_accuracy did not improve from 0.85143
#
# Epoch 175: val_accuracy did not improve from 0.85143
#
# Epoch 176: val_accuracy did not improve from 0.85143
#
# Epoch 177: val_accuracy did not improve from 0.85143
#
# Epoch 178: val_accuracy did not improve from 0.85143
#
# Epoch 179: val_accuracy did not improve from 0.85143
#
# Epoch 180: val_accuracy did not improve from 0.85143
#
# Epoch 181: val_accuracy did not improve from 0.85143
#
# Epoch 182: val_accuracy did not improve from 0.85143
#
# Epoch 183: val_accuracy did not improve from 0.85143
#
# Epoch 184: val_accuracy did not improve from 0.85143
#
# Epoch 185: val_accuracy did not improve from 0.85143
#
# Epoch 186: val_accuracy did not improve from 0.85143
#
# Epoch 187: val_accuracy did not improve from 0.85143
#
# Epoch 188: val_accuracy did not improve from 0.85143
#
# Epoch 189: val_accuracy did not improve from 0.85143
#
# Epoch 190: val_accuracy did not improve from 0.85143
#
# Epoch 191: val_accuracy did not improve from 0.85143
#
# Epoch 192: val_accuracy did not improve from 0.85143
#
# Epoch 193: val_accuracy did not improve from 0.85143
#
# Epoch 194: val_accuracy did not improve from 0.85143
#
# Epoch 195: val_accuracy did not improve from 0.85143
#
# Epoch 196: val_accuracy did not improve from 0.85143
#
# Epoch 197: val_accuracy did not improve from 0.85143
#
# Epoch 198: val_accuracy did not improve from 0.85143
#
# Epoch 199: val_accuracy did not improve from 0.85143
#
# Epoch 200: val_accuracy did not improve from 0.85143
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1292 - accuracy: 0.8514
# 2:200 0.8514285683631897
#
# Epoch 1: val_accuracy improved from -inf to 0.70286, saving model to /content/checkpts_2_400.hdf5
#
# Epoch 2: val_accuracy did not improve from 0.70286
#
# Epoch 3: val_accuracy did not improve from 0.70286
#
# Epoch 4: val_accuracy did not improve from 0.70286
#
# Epoch 5: val_accuracy did not improve from 0.70286
#
# Epoch 6: val_accuracy did not improve from 0.70286
#
# Epoch 7: val_accuracy did not improve from 0.70286
#
# Epoch 8: val_accuracy did not improve from 0.70286
#
# Epoch 9: val_accuracy improved from 0.70286 to 0.71429, saving model to /content/checkpts_2_400.hdf5
#
# Epoch 10: val_accuracy improved from 0.71429 to 0.78286, saving model to /content/checkpts_2_400.hdf5
#
# Epoch 11: val_accuracy did not improve from 0.78286
#
# Epoch 12: val_accuracy did not improve from 0.78286
#
# Epoch 13: val_accuracy improved from 0.78286 to 0.81143, saving model to /content/checkpts_2_400.hdf5
#
# Epoch 14: val_accuracy improved from 0.81143 to 0.81714, saving model to /content/checkpts_2_400.hdf5
#
# Epoch 15: val_accuracy did not improve from 0.81714
#
# Epoch 16: val_accuracy improved from 0.81714 to 0.82286, saving model to /content/checkpts_2_400.hdf5
#
# Epoch 17: val_accuracy did not improve from 0.82286
#
# Epoch 18: val_accuracy did not improve from 0.82286
#
# Epoch 19: val_accuracy did not improve from 0.82286
#
# Epoch 20: val_accuracy did not improve from 0.82286
#
# Epoch 21: val_accuracy did not improve from 0.82286
#
# Epoch 22: val_accuracy did not improve from 0.82286
#
# Epoch 23: val_accuracy did not improve from 0.82286
#
# Epoch 24: val_accuracy did not improve from 0.82286
#
# Epoch 25: val_accuracy did not improve from 0.82286
#
# Epoch 26: val_accuracy improved from 0.82286 to 0.84000, saving model to /content/checkpts_2_400.hdf5
#
# Epoch 27: val_accuracy did not improve from 0.84000
#
# Epoch 28: val_accuracy did not improve from 0.84000
#
# Epoch 29: val_accuracy did not improve from 0.84000
#
# Epoch 30: val_accuracy did not improve from 0.84000
#
# Epoch 31: val_accuracy did not improve from 0.84000
#
# Epoch 32: val_accuracy did not improve from 0.84000
#
# Epoch 33: val_accuracy improved from 0.84000 to 0.84571, saving model to /content/checkpts_2_400.hdf5
#
# Epoch 34: val_accuracy did not improve from 0.84571
#
# Epoch 35: val_accuracy did not improve from 0.84571
#
# Epoch 36: val_accuracy did not improve from 0.84571
#
# Epoch 37: val_accuracy did not improve from 0.84571
#
# Epoch 38: val_accuracy did not improve from 0.84571
#
# Epoch 39: val_accuracy did not improve from 0.84571
#
# Epoch 40: val_accuracy did not improve from 0.84571
#
# Epoch 41: val_accuracy did not improve from 0.84571
#
# Epoch 42: val_accuracy did not improve from 0.84571
#
# Epoch 43: val_accuracy did not improve from 0.84571
#
# Epoch 44: val_accuracy did not improve from 0.84571
#
# Epoch 45: val_accuracy did not improve from 0.84571
#
# Epoch 46: val_accuracy did not improve from 0.84571
#
# Epoch 47: val_accuracy did not improve from 0.84571
#
# Epoch 48: val_accuracy did not improve from 0.84571
#
# Epoch 49: val_accuracy did not improve from 0.84571
#
# Epoch 50: val_accuracy did not improve from 0.84571
#
# Epoch 51: val_accuracy did not improve from 0.84571
#
# Epoch 52: val_accuracy did not improve from 0.84571
#
# Epoch 53: val_accuracy did not improve from 0.84571
#
# Epoch 54: val_accuracy did not improve from 0.84571
#
# Epoch 55: val_accuracy did not improve from 0.84571
#
# Epoch 56: val_accuracy did not improve from 0.84571
#
# Epoch 57: val_accuracy did not improve from 0.84571
#
# Epoch 58: val_accuracy did not improve from 0.84571
#
# Epoch 59: val_accuracy did not improve from 0.84571
#
# Epoch 60: val_accuracy did not improve from 0.84571
#
# Epoch 61: val_accuracy did not improve from 0.84571
#
# Epoch 62: val_accuracy did not improve from 0.84571
#
# Epoch 63: val_accuracy did not improve from 0.84571
#
# Epoch 64: val_accuracy did not improve from 0.84571
#
# Epoch 65: val_accuracy did not improve from 0.84571
#
# Epoch 66: val_accuracy did not improve from 0.84571
#
# Epoch 67: val_accuracy did not improve from 0.84571
#
# Epoch 68: val_accuracy did not improve from 0.84571
#
# Epoch 69: val_accuracy did not improve from 0.84571
#
# Epoch 70: val_accuracy did not improve from 0.84571
#
# Epoch 71: val_accuracy did not improve from 0.84571
#
# Epoch 72: val_accuracy did not improve from 0.84571
#
# Epoch 73: val_accuracy did not improve from 0.84571
#
# Epoch 74: val_accuracy did not improve from 0.84571
#
# Epoch 75: val_accuracy did not improve from 0.84571
#
# Epoch 76: val_accuracy did not improve from 0.84571
#
# Epoch 77: val_accuracy did not improve from 0.84571
#
# Epoch 78: val_accuracy did not improve from 0.84571
#
# Epoch 79: val_accuracy did not improve from 0.84571
#
# Epoch 80: val_accuracy did not improve from 0.84571
#
# Epoch 81: val_accuracy did not improve from 0.84571
#
# Epoch 82: val_accuracy did not improve from 0.84571
#
# Epoch 83: val_accuracy did not improve from 0.84571
#
# Epoch 84: val_accuracy did not improve from 0.84571
#
# Epoch 85: val_accuracy did not improve from 0.84571
#
# Epoch 86: val_accuracy did not improve from 0.84571
#
# Epoch 87: val_accuracy did not improve from 0.84571
#
# Epoch 88: val_accuracy did not improve from 0.84571
#
# Epoch 89: val_accuracy did not improve from 0.84571
#
# Epoch 90: val_accuracy did not improve from 0.84571
#
# Epoch 91: val_accuracy did not improve from 0.84571
#
# Epoch 92: val_accuracy did not improve from 0.84571
#
# Epoch 93: val_accuracy did not improve from 0.84571
#
# Epoch 94: val_accuracy did not improve from 0.84571
#
# Epoch 95: val_accuracy did not improve from 0.84571
#
# Epoch 96: val_accuracy did not improve from 0.84571
#
# Epoch 97: val_accuracy did not improve from 0.84571
#
# Epoch 98: val_accuracy did not improve from 0.84571
#
# Epoch 99: val_accuracy did not improve from 0.84571
#
# Epoch 100: val_accuracy did not improve from 0.84571
#
# Epoch 101: val_accuracy did not improve from 0.84571
#
# Epoch 102: val_accuracy did not improve from 0.84571
#
# Epoch 103: val_accuracy did not improve from 0.84571
#
# Epoch 104: val_accuracy did not improve from 0.84571
#
# Epoch 105: val_accuracy did not improve from 0.84571
#
# Epoch 106: val_accuracy did not improve from 0.84571
#
# Epoch 107: val_accuracy did not improve from 0.84571
#
# Epoch 108: val_accuracy did not improve from 0.84571
#
# Epoch 109: val_accuracy did not improve from 0.84571
#
# Epoch 110: val_accuracy did not improve from 0.84571
#
# Epoch 111: val_accuracy did not improve from 0.84571
#
# Epoch 112: val_accuracy did not improve from 0.84571
#
# Epoch 113: val_accuracy did not improve from 0.84571
#
# Epoch 114: val_accuracy did not improve from 0.84571
#
# Epoch 115: val_accuracy did not improve from 0.84571
#
# Epoch 116: val_accuracy did not improve from 0.84571
#
# Epoch 117: val_accuracy did not improve from 0.84571
#
# Epoch 118: val_accuracy did not improve from 0.84571
#
# Epoch 119: val_accuracy did not improve from 0.84571
#
# Epoch 120: val_accuracy did not improve from 0.84571
#
# Epoch 121: val_accuracy did not improve from 0.84571
#
# Epoch 122: val_accuracy did not improve from 0.84571
#
# Epoch 123: val_accuracy did not improve from 0.84571
#
# Epoch 124: val_accuracy did not improve from 0.84571
#
# Epoch 125: val_accuracy did not improve from 0.84571
#
# Epoch 126: val_accuracy did not improve from 0.84571
#
# Epoch 127: val_accuracy did not improve from 0.84571
#
# Epoch 128: val_accuracy did not improve from 0.84571
#
# Epoch 129: val_accuracy did not improve from 0.84571
#
# Epoch 130: val_accuracy did not improve from 0.84571
#
# Epoch 131: val_accuracy did not improve from 0.84571
#
# Epoch 132: val_accuracy did not improve from 0.84571
#
# Epoch 133: val_accuracy did not improve from 0.84571
#
# Epoch 134: val_accuracy did not improve from 0.84571
#
# Epoch 135: val_accuracy did not improve from 0.84571
#
# Epoch 136: val_accuracy did not improve from 0.84571
#
# Epoch 137: val_accuracy did not improve from 0.84571
#
# Epoch 138: val_accuracy did not improve from 0.84571
#
# Epoch 139: val_accuracy did not improve from 0.84571
#
# Epoch 140: val_accuracy did not improve from 0.84571
#
# Epoch 141: val_accuracy did not improve from 0.84571
#
# Epoch 142: val_accuracy did not improve from 0.84571
#
# Epoch 143: val_accuracy did not improve from 0.84571
#
# Epoch 144: val_accuracy did not improve from 0.84571
#
# Epoch 145: val_accuracy did not improve from 0.84571
#
# Epoch 146: val_accuracy did not improve from 0.84571
#
# Epoch 147: val_accuracy did not improve from 0.84571
#
# Epoch 148: val_accuracy did not improve from 0.84571
#
# Epoch 149: val_accuracy did not improve from 0.84571
#
# Epoch 150: val_accuracy did not improve from 0.84571
#
# Epoch 151: val_accuracy did not improve from 0.84571
#
# Epoch 152: val_accuracy did not improve from 0.84571
#
# Epoch 153: val_accuracy did not improve from 0.84571
#
# Epoch 154: val_accuracy did not improve from 0.84571
#
# Epoch 155: val_accuracy did not improve from 0.84571
#
# Epoch 156: val_accuracy did not improve from 0.84571
#
# Epoch 157: val_accuracy did not improve from 0.84571
#
# Epoch 158: val_accuracy did not improve from 0.84571
#
# Epoch 159: val_accuracy did not improve from 0.84571
#
# Epoch 160: val_accuracy did not improve from 0.84571
#
# Epoch 161: val_accuracy did not improve from 0.84571
#
# Epoch 162: val_accuracy did not improve from 0.84571
#
# Epoch 163: val_accuracy did not improve from 0.84571
#
# Epoch 164: val_accuracy did not improve from 0.84571
#
# Epoch 165: val_accuracy did not improve from 0.84571
#
# Epoch 166: val_accuracy did not improve from 0.84571
#
# Epoch 167: val_accuracy did not improve from 0.84571
#
# Epoch 168: val_accuracy did not improve from 0.84571
#
# Epoch 169: val_accuracy did not improve from 0.84571
#
# Epoch 170: val_accuracy did not improve from 0.84571
#
# Epoch 171: val_accuracy did not improve from 0.84571
#
# Epoch 172: val_accuracy did not improve from 0.84571
#
# Epoch 173: val_accuracy did not improve from 0.84571
#
# Epoch 174: val_accuracy did not improve from 0.84571
#
# Epoch 175: val_accuracy did not improve from 0.84571
#
# Epoch 176: val_accuracy did not improve from 0.84571
#
# Epoch 177: val_accuracy did not improve from 0.84571
#
# Epoch 178: val_accuracy did not improve from 0.84571
#
# Epoch 179: val_accuracy did not improve from 0.84571
#
# Epoch 180: val_accuracy did not improve from 0.84571
#
# Epoch 181: val_accuracy did not improve from 0.84571
#
# Epoch 182: val_accuracy did not improve from 0.84571
#
# Epoch 183: val_accuracy did not improve from 0.84571
#
# Epoch 184: val_accuracy did not improve from 0.84571
#
# Epoch 185: val_accuracy did not improve from 0.84571
#
# Epoch 186: val_accuracy did not improve from 0.84571
#
# Epoch 187: val_accuracy did not improve from 0.84571
#
# Epoch 188: val_accuracy did not improve from 0.84571
#
# Epoch 189: val_accuracy did not improve from 0.84571
#
# Epoch 190: val_accuracy did not improve from 0.84571
#
# Epoch 191: val_accuracy did not improve from 0.84571
#
# Epoch 192: val_accuracy did not improve from 0.84571
#
# Epoch 193: val_accuracy did not improve from 0.84571
#
# Epoch 194: val_accuracy did not improve from 0.84571
#
# Epoch 195: val_accuracy did not improve from 0.84571
#
# Epoch 196: val_accuracy did not improve from 0.84571
#
# Epoch 197: val_accuracy did not improve from 0.84571
#
# Epoch 198: val_accuracy did not improve from 0.84571
#
# Epoch 199: val_accuracy did not improve from 0.84571
#
# Epoch 200: val_accuracy did not improve from 0.84571
#
# Epoch 201: val_accuracy did not improve from 0.84571
#
# Epoch 202: val_accuracy did not improve from 0.84571
#
# Epoch 203: val_accuracy did not improve from 0.84571
#
# Epoch 204: val_accuracy did not improve from 0.84571
#
# Epoch 205: val_accuracy did not improve from 0.84571
#
# Epoch 206: val_accuracy did not improve from 0.84571
#
# Epoch 207: val_accuracy did not improve from 0.84571
#
# Epoch 208: val_accuracy did not improve from 0.84571
#
# Epoch 209: val_accuracy did not improve from 0.84571
#
# Epoch 210: val_accuracy did not improve from 0.84571
#
# Epoch 211: val_accuracy did not improve from 0.84571
#
# Epoch 212: val_accuracy did not improve from 0.84571
#
# Epoch 213: val_accuracy did not improve from 0.84571
#
# Epoch 214: val_accuracy did not improve from 0.84571
#
# Epoch 215: val_accuracy did not improve from 0.84571
#
# Epoch 216: val_accuracy did not improve from 0.84571
#
# Epoch 217: val_accuracy did not improve from 0.84571
#
# Epoch 218: val_accuracy did not improve from 0.84571
#
# Epoch 219: val_accuracy did not improve from 0.84571
#
# Epoch 220: val_accuracy improved from 0.84571 to 0.85143, saving model to /content/checkpts_2_400.hdf5
#
# Epoch 221: val_accuracy did not improve from 0.85143
#
# Epoch 222: val_accuracy did not improve from 0.85143
#
# Epoch 223: val_accuracy did not improve from 0.85143
#
# Epoch 224: val_accuracy did not improve from 0.85143
#
# Epoch 225: val_accuracy did not improve from 0.85143
#
# Epoch 226: val_accuracy did not improve from 0.85143
#
# Epoch 227: val_accuracy did not improve from 0.85143
#
# Epoch 228: val_accuracy did not improve from 0.85143
#
# Epoch 229: val_accuracy did not improve from 0.85143
#
# Epoch 230: val_accuracy did not improve from 0.85143
#
# Epoch 231: val_accuracy did not improve from 0.85143
#
# Epoch 232: val_accuracy did not improve from 0.85143
#
# Epoch 233: val_accuracy did not improve from 0.85143
#
# Epoch 234: val_accuracy did not improve from 0.85143
#
# Epoch 235: val_accuracy did not improve from 0.85143
#
# Epoch 236: val_accuracy did not improve from 0.85143
#
# Epoch 237: val_accuracy did not improve from 0.85143
#
# Epoch 238: val_accuracy did not improve from 0.85143
#
# Epoch 239: val_accuracy did not improve from 0.85143
#
# Epoch 240: val_accuracy did not improve from 0.85143
#
# Epoch 241: val_accuracy did not improve from 0.85143
#
# Epoch 242: val_accuracy did not improve from 0.85143
#
# Epoch 243: val_accuracy did not improve from 0.85143
#
# Epoch 244: val_accuracy did not improve from 0.85143
#
# Epoch 245: val_accuracy did not improve from 0.85143
#
# Epoch 246: val_accuracy did not improve from 0.85143
#
# Epoch 247: val_accuracy did not improve from 0.85143
#
# Epoch 248: val_accuracy did not improve from 0.85143
#
# Epoch 249: val_accuracy did not improve from 0.85143
#
# Epoch 250: val_accuracy did not improve from 0.85143
#
# Epoch 251: val_accuracy did not improve from 0.85143
#
# Epoch 252: val_accuracy did not improve from 0.85143
#
# Epoch 253: val_accuracy did not improve from 0.85143
#
# Epoch 254: val_accuracy did not improve from 0.85143
#
# Epoch 255: val_accuracy did not improve from 0.85143
#
# Epoch 256: val_accuracy did not improve from 0.85143
#
# Epoch 257: val_accuracy did not improve from 0.85143
#
# Epoch 258: val_accuracy did not improve from 0.85143
#
# Epoch 259: val_accuracy did not improve from 0.85143
#
# Epoch 260: val_accuracy did not improve from 0.85143
#
# Epoch 261: val_accuracy did not improve from 0.85143
#
# Epoch 262: val_accuracy did not improve from 0.85143
#
# Epoch 263: val_accuracy did not improve from 0.85143
#
# Epoch 264: val_accuracy did not improve from 0.85143
#
# Epoch 265: val_accuracy did not improve from 0.85143
#
# Epoch 266: val_accuracy did not improve from 0.85143
#
# Epoch 267: val_accuracy did not improve from 0.85143
#
# Epoch 268: val_accuracy did not improve from 0.85143
#
# Epoch 269: val_accuracy did not improve from 0.85143
#
# Epoch 270: val_accuracy did not improve from 0.85143
#
# Epoch 271: val_accuracy did not improve from 0.85143
#
# Epoch 272: val_accuracy did not improve from 0.85143
#
# Epoch 273: val_accuracy did not improve from 0.85143
#
# Epoch 274: val_accuracy did not improve from 0.85143
#
# Epoch 275: val_accuracy did not improve from 0.85143
#
# Epoch 276: val_accuracy did not improve from 0.85143
#
# Epoch 277: val_accuracy did not improve from 0.85143
#
# Epoch 278: val_accuracy did not improve from 0.85143
#
# Epoch 279: val_accuracy did not improve from 0.85143
#
# Epoch 280: val_accuracy did not improve from 0.85143
#
# Epoch 281: val_accuracy did not improve from 0.85143
#
# Epoch 282: val_accuracy did not improve from 0.85143
#
# Epoch 283: val_accuracy did not improve from 0.85143
#
# Epoch 284: val_accuracy did not improve from 0.85143
#
# Epoch 285: val_accuracy did not improve from 0.85143
#
# Epoch 286: val_accuracy did not improve from 0.85143
#
# Epoch 287: val_accuracy did not improve from 0.85143
#
# Epoch 288: val_accuracy did not improve from 0.85143
#
# Epoch 289: val_accuracy did not improve from 0.85143
#
# Epoch 290: val_accuracy did not improve from 0.85143
#
# Epoch 291: val_accuracy did not improve from 0.85143
#
# Epoch 292: val_accuracy did not improve from 0.85143
#
# Epoch 293: val_accuracy did not improve from 0.85143
#
# Epoch 294: val_accuracy did not improve from 0.85143
#
# Epoch 295: val_accuracy did not improve from 0.85143
#
# Epoch 296: val_accuracy did not improve from 0.85143
#
# Epoch 297: val_accuracy did not improve from 0.85143
#
# Epoch 298: val_accuracy did not improve from 0.85143
#
# Epoch 299: val_accuracy did not improve from 0.85143
#
# Epoch 300: val_accuracy did not improve from 0.85143
#
# Epoch 301: val_accuracy did not improve from 0.85143
#
# Epoch 302: val_accuracy did not improve from 0.85143
#
# Epoch 303: val_accuracy did not improve from 0.85143
#
# Epoch 304: val_accuracy did not improve from 0.85143
#
# Epoch 305: val_accuracy did not improve from 0.85143
#
# Epoch 306: val_accuracy did not improve from 0.85143
#
# Epoch 307: val_accuracy did not improve from 0.85143
#
# Epoch 308: val_accuracy did not improve from 0.85143
#
# Epoch 309: val_accuracy did not improve from 0.85143
#
# Epoch 310: val_accuracy did not improve from 0.85143
#
# Epoch 311: val_accuracy did not improve from 0.85143
#
# Epoch 312: val_accuracy did not improve from 0.85143
#
# Epoch 313: val_accuracy did not improve from 0.85143
#
# Epoch 314: val_accuracy did not improve from 0.85143
#
# Epoch 315: val_accuracy did not improve from 0.85143
#
# Epoch 316: val_accuracy did not improve from 0.85143
#
# Epoch 317: val_accuracy did not improve from 0.85143
#
# Epoch 318: val_accuracy did not improve from 0.85143
#
# Epoch 319: val_accuracy did not improve from 0.85143
#
# Epoch 320: val_accuracy did not improve from 0.85143
#
# Epoch 321: val_accuracy did not improve from 0.85143
#
# Epoch 322: val_accuracy did not improve from 0.85143
#
# Epoch 323: val_accuracy did not improve from 0.85143
#
# Epoch 324: val_accuracy did not improve from 0.85143
#
# Epoch 325: val_accuracy did not improve from 0.85143
#
# Epoch 326: val_accuracy did not improve from 0.85143
#
# Epoch 327: val_accuracy did not improve from 0.85143
#
# Epoch 328: val_accuracy did not improve from 0.85143
#
# Epoch 329: val_accuracy did not improve from 0.85143
#
# Epoch 330: val_accuracy did not improve from 0.85143
#
# Epoch 331: val_accuracy did not improve from 0.85143
#
# Epoch 332: val_accuracy did not improve from 0.85143
#
# Epoch 333: val_accuracy did not improve from 0.85143
#
# Epoch 334: val_accuracy did not improve from 0.85143
#
# Epoch 335: val_accuracy did not improve from 0.85143
#
# Epoch 336: val_accuracy did not improve from 0.85143
#
# Epoch 337: val_accuracy did not improve from 0.85143
#
# Epoch 338: val_accuracy did not improve from 0.85143
#
# Epoch 339: val_accuracy did not improve from 0.85143
#
# Epoch 340: val_accuracy did not improve from 0.85143
#
# Epoch 341: val_accuracy did not improve from 0.85143
#
# Epoch 342: val_accuracy did not improve from 0.85143
#
# Epoch 343: val_accuracy did not improve from 0.85143
#
# Epoch 344: val_accuracy did not improve from 0.85143
#
# Epoch 345: val_accuracy did not improve from 0.85143
#
# Epoch 346: val_accuracy did not improve from 0.85143
#
# Epoch 347: val_accuracy did not improve from 0.85143
#
# Epoch 348: val_accuracy did not improve from 0.85143
#
# Epoch 349: val_accuracy did not improve from 0.85143
#
# Epoch 350: val_accuracy did not improve from 0.85143
#
# Epoch 351: val_accuracy did not improve from 0.85143
#
# Epoch 352: val_accuracy did not improve from 0.85143
#
# Epoch 353: val_accuracy did not improve from 0.85143
#
# Epoch 354: val_accuracy did not improve from 0.85143
#
# Epoch 355: val_accuracy did not improve from 0.85143
#
# Epoch 356: val_accuracy did not improve from 0.85143
#
# Epoch 357: val_accuracy did not improve from 0.85143
#
# Epoch 358: val_accuracy did not improve from 0.85143
#
# Epoch 359: val_accuracy did not improve from 0.85143
#
# Epoch 360: val_accuracy did not improve from 0.85143
#
# Epoch 361: val_accuracy did not improve from 0.85143
#
# Epoch 362: val_accuracy did not improve from 0.85143
#
# Epoch 363: val_accuracy did not improve from 0.85143
#
# Epoch 364: val_accuracy did not improve from 0.85143
#
# Epoch 365: val_accuracy did not improve from 0.85143
#
# Epoch 366: val_accuracy did not improve from 0.85143
#
# Epoch 367: val_accuracy did not improve from 0.85143
#
# Epoch 368: val_accuracy did not improve from 0.85143
#
# Epoch 369: val_accuracy did not improve from 0.85143
#
# Epoch 370: val_accuracy did not improve from 0.85143
#
# Epoch 371: val_accuracy did not improve from 0.85143
#
# Epoch 372: val_accuracy did not improve from 0.85143
#
# Epoch 373: val_accuracy did not improve from 0.85143
#
# Epoch 374: val_accuracy did not improve from 0.85143
#
# Epoch 375: val_accuracy did not improve from 0.85143
#
# Epoch 376: val_accuracy did not improve from 0.85143
#
# Epoch 377: val_accuracy did not improve from 0.85143
#
# Epoch 378: val_accuracy did not improve from 0.85143
#
# Epoch 379: val_accuracy did not improve from 0.85143
#
# Epoch 380: val_accuracy did not improve from 0.85143
#
# Epoch 381: val_accuracy did not improve from 0.85143
#
# Epoch 382: val_accuracy did not improve from 0.85143
#
# Epoch 383: val_accuracy did not improve from 0.85143
#
# Epoch 384: val_accuracy did not improve from 0.85143
#
# Epoch 385: val_accuracy did not improve from 0.85143
#
# Epoch 386: val_accuracy did not improve from 0.85143
#
# Epoch 387: val_accuracy did not improve from 0.85143
#
# Epoch 388: val_accuracy did not improve from 0.85143
#
# Epoch 389: val_accuracy did not improve from 0.85143
#
# Epoch 390: val_accuracy did not improve from 0.85143
#
# Epoch 391: val_accuracy did not improve from 0.85143
#
# Epoch 392: val_accuracy did not improve from 0.85143
#
# Epoch 393: val_accuracy did not improve from 0.85143
#
# Epoch 394: val_accuracy did not improve from 0.85143
#
# Epoch 395: val_accuracy did not improve from 0.85143
#
# Epoch 396: val_accuracy did not improve from 0.85143
#
# Epoch 397: val_accuracy did not improve from 0.85143
#
# Epoch 398: val_accuracy did not improve from 0.85143
#
# Epoch 399: val_accuracy did not improve from 0.85143
#
# Epoch 400: val_accuracy did not improve from 0.85143
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1248 - accuracy: 0.8514
# 2:400 0.8514285683631897
#
# Epoch 1: val_accuracy improved from -inf to 0.70286, saving model to /content/checkpts_2_800.hdf5
#
# Epoch 2: val_accuracy did not improve from 0.70286
#
# Epoch 3: val_accuracy did not improve from 0.70286
#
# Epoch 4: val_accuracy did not improve from 0.70286
#
# Epoch 5: val_accuracy did not improve from 0.70286
#
# Epoch 6: val_accuracy did not improve from 0.70286
#
# Epoch 7: val_accuracy did not improve from 0.70286
#
# Epoch 8: val_accuracy did not improve from 0.70286
#
# Epoch 9: val_accuracy did not improve from 0.70286
#
# Epoch 10: val_accuracy did not improve from 0.70286
#
# Epoch 11: val_accuracy did not improve from 0.70286
#
# Epoch 12: val_accuracy did not improve from 0.70286
#
# Epoch 13: val_accuracy did not improve from 0.70286
#
# Epoch 14: val_accuracy did not improve from 0.70286
#
# Epoch 15: val_accuracy did not improve from 0.70286
#
# Epoch 16: val_accuracy did not improve from 0.70286
#
# Epoch 17: val_accuracy did not improve from 0.70286
#
# Epoch 18: val_accuracy did not improve from 0.70286
#
# Epoch 19: val_accuracy did not improve from 0.70286
#
# Epoch 20: val_accuracy did not improve from 0.70286
#
# Epoch 21: val_accuracy did not improve from 0.70286
#
# Epoch 22: val_accuracy did not improve from 0.70286
#
# Epoch 23: val_accuracy did not improve from 0.70286
#
# Epoch 24: val_accuracy did not improve from 0.70286
#
# Epoch 25: val_accuracy did not improve from 0.70286
#
# Epoch 26: val_accuracy improved from 0.70286 to 0.71429, saving model to /content/checkpts_2_800.hdf5
#
# Epoch 27: val_accuracy improved from 0.71429 to 0.72000, saving model to /content/checkpts_2_800.hdf5
#
# Epoch 28: val_accuracy improved from 0.72000 to 0.73143, saving model to /content/checkpts_2_800.hdf5
#
# Epoch 29: val_accuracy did not improve from 0.73143
#
# Epoch 30: val_accuracy improved from 0.73143 to 0.74857, saving model to /content/checkpts_2_800.hdf5
#
# Epoch 31: val_accuracy did not improve from 0.74857
#
# Epoch 32: val_accuracy improved from 0.74857 to 0.76571, saving model to /content/checkpts_2_800.hdf5
#
# Epoch 33: val_accuracy did not improve from 0.76571
#
# Epoch 34: val_accuracy improved from 0.76571 to 0.77143, saving model to /content/checkpts_2_800.hdf5
#
# Epoch 35: val_accuracy did not improve from 0.77143
#
# Epoch 36: val_accuracy improved from 0.77143 to 0.78857, saving model to /content/checkpts_2_800.hdf5
#
# Epoch 37: val_accuracy improved from 0.78857 to 0.81714, saving model to /content/checkpts_2_800.hdf5
#
# Epoch 38: val_accuracy did not improve from 0.81714
#
# Epoch 39: val_accuracy did not improve from 0.81714
#
# Epoch 40: val_accuracy did not improve from 0.81714
#
# Epoch 41: val_accuracy did not improve from 0.81714
#
# Epoch 42: val_accuracy did not improve from 0.81714
#
# Epoch 43: val_accuracy did not improve from 0.81714
#
# Epoch 44: val_accuracy did not improve from 0.81714
#
# Epoch 45: val_accuracy improved from 0.81714 to 0.82286, saving model to /content/checkpts_2_800.hdf5
#
# Epoch 46: val_accuracy did not improve from 0.82286
#
# Epoch 47: val_accuracy did not improve from 0.82286
#
# Epoch 48: val_accuracy did not improve from 0.82286
#
# Epoch 49: val_accuracy did not improve from 0.82286
#
# Epoch 50: val_accuracy did not improve from 0.82286
#
# Epoch 51: val_accuracy did not improve from 0.82286
#
# Epoch 52: val_accuracy did not improve from 0.82286
#
# Epoch 53: val_accuracy did not improve from 0.82286
#
# Epoch 54: val_accuracy did not improve from 0.82286
#
# Epoch 55: val_accuracy did not improve from 0.82286
#
# Epoch 56: val_accuracy did not improve from 0.82286
#
# Epoch 57: val_accuracy did not improve from 0.82286
#
# Epoch 58: val_accuracy improved from 0.82286 to 0.82857, saving model to /content/checkpts_2_800.hdf5
#
# Epoch 59: val_accuracy did not improve from 0.82857
#
# Epoch 60: val_accuracy did not improve from 0.82857
#
# Epoch 61: val_accuracy did not improve from 0.82857
#
# Epoch 62: val_accuracy improved from 0.82857 to 0.84000, saving model to /content/checkpts_2_800.hdf5
#
# Epoch 63: val_accuracy did not improve from 0.84000
#
# Epoch 64: val_accuracy did not improve from 0.84000
#
# Epoch 65: val_accuracy did not improve from 0.84000
#
# Epoch 66: val_accuracy did not improve from 0.84000
#
# Epoch 67: val_accuracy did not improve from 0.84000
#
# Epoch 68: val_accuracy did not improve from 0.84000
#
# Epoch 69: val_accuracy did not improve from 0.84000
#
# Epoch 70: val_accuracy did not improve from 0.84000
#
# Epoch 71: val_accuracy did not improve from 0.84000
#
# Epoch 72: val_accuracy did not improve from 0.84000
#
# Epoch 73: val_accuracy did not improve from 0.84000
#
# Epoch 74: val_accuracy did not improve from 0.84000
#
# Epoch 75: val_accuracy did not improve from 0.84000
#
# Epoch 76: val_accuracy did not improve from 0.84000
#
# Epoch 77: val_accuracy did not improve from 0.84000
#
# Epoch 78: val_accuracy did not improve from 0.84000
#
# Epoch 79: val_accuracy did not improve from 0.84000
#
# Epoch 80: val_accuracy did not improve from 0.84000
#
# Epoch 81: val_accuracy did not improve from 0.84000
#
# Epoch 82: val_accuracy did not improve from 0.84000
#
# Epoch 83: val_accuracy did not improve from 0.84000
#
# Epoch 84: val_accuracy did not improve from 0.84000
#
# Epoch 85: val_accuracy did not improve from 0.84000
#
# Epoch 86: val_accuracy did not improve from 0.84000
#
# Epoch 87: val_accuracy did not improve from 0.84000
#
# Epoch 88: val_accuracy did not improve from 0.84000
#
# Epoch 89: val_accuracy did not improve from 0.84000
#
# Epoch 90: val_accuracy did not improve from 0.84000
#
# Epoch 91: val_accuracy did not improve from 0.84000
#
# Epoch 92: val_accuracy did not improve from 0.84000
#
# Epoch 93: val_accuracy did not improve from 0.84000
#
# Epoch 94: val_accuracy did not improve from 0.84000
#
# Epoch 95: val_accuracy did not improve from 0.84000
#
# Epoch 96: val_accuracy did not improve from 0.84000
#
# Epoch 97: val_accuracy did not improve from 0.84000
#
# Epoch 98: val_accuracy did not improve from 0.84000
#
# Epoch 99: val_accuracy did not improve from 0.84000
#
# Epoch 100: val_accuracy did not improve from 0.84000
#
# Epoch 101: val_accuracy did not improve from 0.84000
#
# Epoch 102: val_accuracy did not improve from 0.84000
#
# Epoch 103: val_accuracy did not improve from 0.84000
#
# Epoch 104: val_accuracy did not improve from 0.84000
#
# Epoch 105: val_accuracy did not improve from 0.84000
#
# Epoch 106: val_accuracy did not improve from 0.84000
#
# Epoch 107: val_accuracy did not improve from 0.84000
#
# Epoch 108: val_accuracy did not improve from 0.84000
#
# Epoch 109: val_accuracy did not improve from 0.84000
#
# Epoch 110: val_accuracy did not improve from 0.84000
#
# Epoch 111: val_accuracy did not improve from 0.84000
#
# Epoch 112: val_accuracy did not improve from 0.84000
#
# Epoch 113: val_accuracy did not improve from 0.84000
#
# Epoch 114: val_accuracy did not improve from 0.84000
#
# Epoch 115: val_accuracy did not improve from 0.84000
#
# Epoch 116: val_accuracy did not improve from 0.84000
#
# Epoch 117: val_accuracy did not improve from 0.84000
#
# Epoch 118: val_accuracy did not improve from 0.84000
#
# Epoch 119: val_accuracy did not improve from 0.84000
#
# Epoch 120: val_accuracy did not improve from 0.84000
#
# Epoch 121: val_accuracy did not improve from 0.84000
#
# Epoch 122: val_accuracy did not improve from 0.84000
#
# Epoch 123: val_accuracy did not improve from 0.84000
#
# Epoch 124: val_accuracy did not improve from 0.84000
#
# Epoch 125: val_accuracy did not improve from 0.84000
#
# Epoch 126: val_accuracy did not improve from 0.84000
#
# Epoch 127: val_accuracy did not improve from 0.84000
#
# Epoch 128: val_accuracy did not improve from 0.84000
#
# Epoch 129: val_accuracy did not improve from 0.84000
#
# Epoch 130: val_accuracy did not improve from 0.84000
#
# Epoch 131: val_accuracy did not improve from 0.84000
#
# Epoch 132: val_accuracy did not improve from 0.84000
#
# Epoch 133: val_accuracy did not improve from 0.84000
#
# Epoch 134: val_accuracy did not improve from 0.84000
#
# Epoch 135: val_accuracy did not improve from 0.84000
#
# Epoch 136: val_accuracy did not improve from 0.84000
#
# Epoch 137: val_accuracy did not improve from 0.84000
#
# Epoch 138: val_accuracy did not improve from 0.84000
#
# Epoch 139: val_accuracy did not improve from 0.84000
#
# Epoch 140: val_accuracy did not improve from 0.84000
#
# Epoch 141: val_accuracy did not improve from 0.84000
#
# Epoch 142: val_accuracy did not improve from 0.84000
#
# Epoch 143: val_accuracy did not improve from 0.84000
#
# Epoch 144: val_accuracy did not improve from 0.84000
#
# Epoch 145: val_accuracy did not improve from 0.84000
#
# Epoch 146: val_accuracy did not improve from 0.84000
#
# Epoch 147: val_accuracy did not improve from 0.84000
#
# Epoch 148: val_accuracy did not improve from 0.84000
#
# Epoch 149: val_accuracy did not improve from 0.84000
#
# Epoch 150: val_accuracy did not improve from 0.84000
#
# Epoch 151: val_accuracy did not improve from 0.84000
#
# Epoch 152: val_accuracy did not improve from 0.84000
#
# Epoch 153: val_accuracy did not improve from 0.84000
#
# Epoch 154: val_accuracy did not improve from 0.84000
#
# Epoch 155: val_accuracy did not improve from 0.84000
#
# Epoch 156: val_accuracy did not improve from 0.84000
#
# Epoch 157: val_accuracy did not improve from 0.84000
#
# Epoch 158: val_accuracy did not improve from 0.84000
#
# Epoch 159: val_accuracy did not improve from 0.84000
#
# Epoch 160: val_accuracy did not improve from 0.84000
#
# Epoch 161: val_accuracy improved from 0.84000 to 0.84571, saving model to /content/checkpts_2_800.hdf5
#
# Epoch 162: val_accuracy did not improve from 0.84571
#
# Epoch 163: val_accuracy did not improve from 0.84571
#
# Epoch 164: val_accuracy did not improve from 0.84571
#
# Epoch 165: val_accuracy did not improve from 0.84571
#
# Epoch 166: val_accuracy did not improve from 0.84571
#
# Epoch 167: val_accuracy did not improve from 0.84571
#
# Epoch 168: val_accuracy did not improve from 0.84571
#
# Epoch 169: val_accuracy did not improve from 0.84571
#
# Epoch 170: val_accuracy did not improve from 0.84571
#
# Epoch 171: val_accuracy did not improve from 0.84571
#
# Epoch 172: val_accuracy did not improve from 0.84571
#
# Epoch 173: val_accuracy did not improve from 0.84571
#
# Epoch 174: val_accuracy did not improve from 0.84571
#
# Epoch 175: val_accuracy did not improve from 0.84571
#
# Epoch 176: val_accuracy did not improve from 0.84571
#
# Epoch 177: val_accuracy did not improve from 0.84571
#
# Epoch 178: val_accuracy did not improve from 0.84571
#
# Epoch 179: val_accuracy did not improve from 0.84571
#
# Epoch 180: val_accuracy did not improve from 0.84571
#
# Epoch 181: val_accuracy did not improve from 0.84571
#
# Epoch 182: val_accuracy did not improve from 0.84571
#
# Epoch 183: val_accuracy did not improve from 0.84571
#
# Epoch 184: val_accuracy did not improve from 0.84571
#
# Epoch 185: val_accuracy did not improve from 0.84571
#
# Epoch 186: val_accuracy did not improve from 0.84571
#
# Epoch 187: val_accuracy did not improve from 0.84571
#
# Epoch 188: val_accuracy did not improve from 0.84571
#
# Epoch 189: val_accuracy did not improve from 0.84571
#
# Epoch 190: val_accuracy did not improve from 0.84571
#
# Epoch 191: val_accuracy did not improve from 0.84571
#
# Epoch 192: val_accuracy did not improve from 0.84571
#
# Epoch 193: val_accuracy did not improve from 0.84571
#
# Epoch 194: val_accuracy did not improve from 0.84571
#
# Epoch 195: val_accuracy did not improve from 0.84571
#
# Epoch 196: val_accuracy did not improve from 0.84571
#
# Epoch 197: val_accuracy did not improve from 0.84571
#
# Epoch 198: val_accuracy did not improve from 0.84571
#
# Epoch 199: val_accuracy did not improve from 0.84571
#
# Epoch 200: val_accuracy did not improve from 0.84571
#
# Epoch 201: val_accuracy did not improve from 0.84571
#
# Epoch 202: val_accuracy did not improve from 0.84571
#
# Epoch 203: val_accuracy did not improve from 0.84571
#
# Epoch 204: val_accuracy did not improve from 0.84571
#
# Epoch 205: val_accuracy did not improve from 0.84571
#
# Epoch 206: val_accuracy did not improve from 0.84571
#
# Epoch 207: val_accuracy did not improve from 0.84571
#
# Epoch 208: val_accuracy did not improve from 0.84571
#
# Epoch 209: val_accuracy did not improve from 0.84571
#
# Epoch 210: val_accuracy did not improve from 0.84571
#
# Epoch 211: val_accuracy did not improve from 0.84571
#
# Epoch 212: val_accuracy did not improve from 0.84571
#
# Epoch 213: val_accuracy did not improve from 0.84571
#
# Epoch 214: val_accuracy did not improve from 0.84571
#
# Epoch 215: val_accuracy did not improve from 0.84571
#
# Epoch 216: val_accuracy did not improve from 0.84571
#
# Epoch 217: val_accuracy did not improve from 0.84571
#
# Epoch 218: val_accuracy did not improve from 0.84571
#
# Epoch 219: val_accuracy did not improve from 0.84571
#
# Epoch 220: val_accuracy did not improve from 0.84571
#
# Epoch 221: val_accuracy did not improve from 0.84571
#
# Epoch 222: val_accuracy did not improve from 0.84571
#
# Epoch 223: val_accuracy did not improve from 0.84571
#
# Epoch 224: val_accuracy did not improve from 0.84571
#
# Epoch 225: val_accuracy did not improve from 0.84571
#
# Epoch 226: val_accuracy did not improve from 0.84571
#
# Epoch 227: val_accuracy did not improve from 0.84571
#
# Epoch 228: val_accuracy did not improve from 0.84571
#
# Epoch 229: val_accuracy did not improve from 0.84571
#
# Epoch 230: val_accuracy did not improve from 0.84571
#
# Epoch 231: val_accuracy did not improve from 0.84571
#
# Epoch 232: val_accuracy did not improve from 0.84571
#
# Epoch 233: val_accuracy did not improve from 0.84571
#
# Epoch 234: val_accuracy did not improve from 0.84571
#
# Epoch 235: val_accuracy did not improve from 0.84571
#
# Epoch 236: val_accuracy did not improve from 0.84571
#
# Epoch 237: val_accuracy did not improve from 0.84571
#
# Epoch 238: val_accuracy did not improve from 0.84571
#
# Epoch 239: val_accuracy did not improve from 0.84571
#
# Epoch 240: val_accuracy did not improve from 0.84571
#
# Epoch 241: val_accuracy did not improve from 0.84571
#
# Epoch 242: val_accuracy did not improve from 0.84571
#
# Epoch 243: val_accuracy did not improve from 0.84571
#
# Epoch 244: val_accuracy did not improve from 0.84571
#
# Epoch 245: val_accuracy did not improve from 0.84571
#
# Epoch 246: val_accuracy did not improve from 0.84571
#
# Epoch 247: val_accuracy did not improve from 0.84571
#
# Epoch 248: val_accuracy did not improve from 0.84571
#
# Epoch 249: val_accuracy did not improve from 0.84571
#
# Epoch 250: val_accuracy did not improve from 0.84571
#
# Epoch 251: val_accuracy did not improve from 0.84571
#
# Epoch 252: val_accuracy did not improve from 0.84571
#
# Epoch 253: val_accuracy did not improve from 0.84571
#
# Epoch 254: val_accuracy did not improve from 0.84571
#
# Epoch 255: val_accuracy did not improve from 0.84571
#
# Epoch 256: val_accuracy did not improve from 0.84571
#
# Epoch 257: val_accuracy did not improve from 0.84571
#
# Epoch 258: val_accuracy did not improve from 0.84571
#
# Epoch 259: val_accuracy did not improve from 0.84571
#
# ...
#
# Epoch 507: val_accuracy did not improve from 0.84571
#
# Epoch 508: val_accuracy did not improve from 0.84571
#
# Epoch 509: val_accuracy did not improve from 0.84571
#
# Epoch 510: val_accuracy did not improve from 0.84571
#
# Epoch 511: val_accuracy did not improve from 0.84571
#
# Epoch 512: val_accuracy did not improve from 0.84571
#
# Epoch 513: val_accuracy did not improve from 0.84571
#
# Epoch 514: val_accuracy did not improve from 0.84571
#
# Epoch 515: val_accuracy did not improve from 0.84571
#
# Epoch 516: val_accuracy did not improve from 0.84571
#
# Epoch 517: val_accuracy did not improve from 0.84571
#
# Epoch 518: val_accuracy did not improve from 0.84571
#
# Epoch 519: val_accuracy did not improve from 0.84571
#
# Epoch 520: val_accuracy did not improve from 0.84571
#
# Epoch 521: val_accuracy did not improve from 0.84571
#
# Epoch 522: val_accuracy did not improve from 0.84571
#
# Epoch 523: val_accuracy did not improve from 0.84571
#
# Epoch 524: val_accuracy did not improve from 0.84571
#
# Epoch 525: val_accuracy did not improve from 0.84571
#
# Epoch 526: val_accuracy did not improve from 0.84571
#
# Epoch 527: val_accuracy did not improve from 0.84571
#
# Epoch 528: val_accuracy did not improve from 0.84571
#
# Epoch 529: val_accuracy did not improve from 0.84571
#
# Epoch 530: val_accuracy did not improve from 0.84571
#
# Epoch 531: val_accuracy did not improve from 0.84571
#
# Epoch 532: val_accuracy did not improve from 0.84571
#
# Epoch 533: val_accuracy did not improve from 0.84571
#
# Epoch 534: val_accuracy did not improve from 0.84571
#
# Epoch 535: val_accuracy did not improve from 0.84571
#
# Epoch 536: val_accuracy did not improve from 0.84571
#
# Epoch 537: val_accuracy did not improve from 0.84571
#
# Epoch 538: val_accuracy did not improve from 0.84571
#
# Epoch 539: val_accuracy did not improve from 0.84571
#
# Epoch 540: val_accuracy did not improve from 0.84571
#
# Epoch 541: val_accuracy did not improve from 0.84571
#
# Epoch 542: val_accuracy did not improve from 0.84571
#
# Epoch 543: val_accuracy did not improve from 0.84571
#
# Epoch 544: val_accuracy did not improve from 0.84571
#
# Epoch 545: val_accuracy did not improve from 0.84571
#
# Epoch 546: val_accuracy did not improve from 0.84571
#
# Epoch 547: val_accuracy did not improve from 0.84571
#
# Epoch 548: val_accuracy did not improve from 0.84571
#
# Epoch 549: val_accuracy did not improve from 0.84571
#
# Epoch 550: val_accuracy did not improve from 0.84571
#
# Epoch 551: val_accuracy did not improve from 0.84571
#
# Epoch 552: val_accuracy did not improve from 0.84571
#
# Epoch 553: val_accuracy did not improve from 0.84571
#
# Epoch 554: val_accuracy did not improve from 0.84571
#
# Epoch 555: val_accuracy did not improve from 0.84571
#
# Epoch 556: val_accuracy did not improve from 0.84571
#
# Epoch 557: val_accuracy did not improve from 0.84571
#
# Epoch 558: val_accuracy did not improve from 0.84571
#
# Epoch 559: val_accuracy did not improve from 0.84571
#
# Epoch 560: val_accuracy did not improve from 0.84571
#
# Epoch 561: val_accuracy did not improve from 0.84571
#
# Epoch 562: val_accuracy did not improve from 0.84571
#
# Epoch 563: val_accuracy did not improve from 0.84571
#
# Epoch 564: val_accuracy did not improve from 0.84571
#
# Epoch 565: val_accuracy did not improve from 0.84571
#
# Epoch 566: val_accuracy did not improve from 0.84571
#
# Epoch 567: val_accuracy did not improve from 0.84571
#
# Epoch 568: val_accuracy did not improve from 0.84571
#
# Epoch 569: val_accuracy did not improve from 0.84571
#
# Epoch 570: val_accuracy did not improve from 0.84571
#
# Epoch 571: val_accuracy did not improve from 0.84571
#
# Epoch 572: val_accuracy did not improve from 0.84571
#
# Epoch 573: val_accuracy did not improve from 0.84571
#
# Epoch 574: val_accuracy did not improve from 0.84571
#
# Epoch 575: val_accuracy did not improve from 0.84571
#
# Epoch 576: val_accuracy did not improve from 0.84571
#
# Epoch 577: val_accuracy did not improve from 0.84571
#
# Epoch 578: val_accuracy did not improve from 0.84571
#
# Epoch 579: val_accuracy did not improve from 0.84571
#
# Epoch 580: val_accuracy did not improve from 0.84571
#
# Epoch 581: val_accuracy did not improve from 0.84571
#
# Epoch 582: val_accuracy did not improve from 0.84571
#
# Epoch 583: val_accuracy did not improve from 0.84571
#
# Epoch 584: val_accuracy did not improve from 0.84571
#
# Epoch 585: val_accuracy did not improve from 0.84571
#
# Epoch 586: val_accuracy did not improve from 0.84571
#
# Epoch 587: val_accuracy did not improve from 0.84571
#
# Epoch 588: val_accuracy did not improve from 0.84571
#
# Epoch 589: val_accuracy did not improve from 0.84571
#
# Epoch 590: val_accuracy did not improve from 0.84571
#
# Epoch 591: val_accuracy did not improve from 0.84571
#
# Epoch 592: val_accuracy did not improve from 0.84571
#
# Epoch 593: val_accuracy did not improve from 0.84571
#
# Epoch 594: val_accuracy did not improve from 0.84571
#
# Epoch 595: val_accuracy did not improve from 0.84571
#
# Epoch 596: val_accuracy did not improve from 0.84571
#
# Epoch 597: val_accuracy did not improve from 0.84571
#
# Epoch 598: val_accuracy did not improve from 0.84571
#
# Epoch 599: val_accuracy did not improve from 0.84571
#
# Epoch 600: val_accuracy did not improve from 0.84571
#
# Epoch 601: val_accuracy did not improve from 0.84571
#
# Epoch 602: val_accuracy did not improve from 0.84571
#
# Epoch 603: val_accuracy did not improve from 0.84571
#
# Epoch 604: val_accuracy did not improve from 0.84571
#
# Epoch 605: val_accuracy did not improve from 0.84571
#
# Epoch 606: val_accuracy did not improve from 0.84571
#
# Epoch 607: val_accuracy did not improve from 0.84571
#
# Epoch 608: val_accuracy did not improve from 0.84571
#
# Epoch 609: val_accuracy did not improve from 0.84571
#
# Epoch 610: val_accuracy did not improve from 0.84571
#
# Epoch 611: val_accuracy did not improve from 0.84571
#
# Epoch 612: val_accuracy did not improve from 0.84571
#
# Epoch 613: val_accuracy did not improve from 0.84571
#
# Epoch 614: val_accuracy did not improve from 0.84571
#
# Epoch 615: val_accuracy did not improve from 0.84571
#
# Epoch 616: val_accuracy did not improve from 0.84571
#
# Epoch 617: val_accuracy did not improve from 0.84571
#
# Epoch 618: val_accuracy did not improve from 0.84571
#
# Epoch 619: val_accuracy did not improve from 0.84571
#
# Epoch 620: val_accuracy did not improve from 0.84571
#
# Epoch 621: val_accuracy did not improve from 0.84571
#
# Epoch 622: val_accuracy did not improve from 0.84571
#
# Epoch 623: val_accuracy did not improve from 0.84571
#
# Epoch 624: val_accuracy did not improve from 0.84571
#
# Epoch 625: val_accuracy did not improve from 0.84571
#
# Epoch 626: val_accuracy did not improve from 0.84571
#
# Epoch 627: val_accuracy did not improve from 0.84571
#
# Epoch 628: val_accuracy did not improve from 0.84571
#
# Epoch 629: val_accuracy did not improve from 0.84571
#
# Epoch 630: val_accuracy did not improve from 0.84571
#
# Epoch 631: val_accuracy did not improve from 0.84571
#
# Epoch 632: val_accuracy did not improve from 0.84571
#
# Epoch 633: val_accuracy did not improve from 0.84571
#
# Epoch 634: val_accuracy did not improve from 0.84571
#
# Epoch 635: val_accuracy did not improve from 0.84571
#
# Epoch 636: val_accuracy did not improve from 0.84571
#
# Epoch 637: val_accuracy did not improve from 0.84571
#
# Epoch 638: val_accuracy did not improve from 0.84571
#
# Epoch 639: val_accuracy did not improve from 0.84571
#
# Epoch 640: val_accuracy did not improve from 0.84571
#
# Epoch 641: val_accuracy did not improve from 0.84571
#
# Epoch 642: val_accuracy did not improve from 0.84571
#
# Epoch 643: val_accuracy did not improve from 0.84571
#
# Epoch 644: val_accuracy did not improve from 0.84571
#
# Epoch 645: val_accuracy did not improve from 0.84571
#
# Epoch 646: val_accuracy did not improve from 0.84571
#
# Epoch 647: val_accuracy did not improve from 0.84571
#
# Epoch 648: val_accuracy did not improve from 0.84571
#
# Epoch 649: val_accuracy did not improve from 0.84571
#
# Epoch 650: val_accuracy did not improve from 0.84571
#
# Epoch 651: val_accuracy did not improve from 0.84571
#
# Epoch 652: val_accuracy did not improve from 0.84571
#
# Epoch 653: val_accuracy did not improve from 0.84571
#
# Epoch 654: val_accuracy did not improve from 0.84571
#
# Epoch 655: val_accuracy did not improve from 0.84571
#
# Epoch 656: val_accuracy did not improve from 0.84571
#
# Epoch 657: val_accuracy did not improve from 0.84571
#
# Epoch 658: val_accuracy did not improve from 0.84571
#
# Epoch 659: val_accuracy did not improve from 0.84571
#
# Epoch 660: val_accuracy did not improve from 0.84571
#
# Epoch 661: val_accuracy did not improve from 0.84571
#
# Epoch 662: val_accuracy did not improve from 0.84571
#
# Epoch 663: val_accuracy did not improve from 0.84571
#
# Epoch 664: val_accuracy did not improve from 0.84571
#
# Epoch 665: val_accuracy did not improve from 0.84571
#
# Epoch 666: val_accuracy did not improve from 0.84571
#
# Epoch 667: val_accuracy did not improve from 0.84571
#
# Epoch 668: val_accuracy did not improve from 0.84571
#
# Epoch 669: val_accuracy did not improve from 0.84571
#
# Epoch 670: val_accuracy did not improve from 0.84571
#
# Epoch 671: val_accuracy did not improve from 0.84571
#
# Epoch 672: val_accuracy did not improve from 0.84571
#
# Epoch 673: val_accuracy did not improve from 0.84571
#
# Epoch 674: val_accuracy did not improve from 0.84571
#
# Epoch 675: val_accuracy did not improve from 0.84571
#
# Epoch 676: val_accuracy did not improve from 0.84571
#
# Epoch 677: val_accuracy did not improve from 0.84571
#
# Epoch 678: val_accuracy did not improve from 0.84571
#
# Epoch 679: val_accuracy did not improve from 0.84571
#
# Epoch 680: val_accuracy did not improve from 0.84571
#
# Epoch 681: val_accuracy did not improve from 0.84571
#
# Epoch 682: val_accuracy did not improve from 0.84571
#
# Epoch 683: val_accuracy did not improve from 0.84571
#
# Epoch 684: val_accuracy did not improve from 0.84571
#
# Epoch 685: val_accuracy did not improve from 0.84571
#
# Epoch 686: val_accuracy did not improve from 0.84571
#
# Epoch 687: val_accuracy did not improve from 0.84571
#
# Epoch 688: val_accuracy did not improve from 0.84571
#
# Epoch 689: val_accuracy did not improve from 0.84571
#
# Epoch 690: val_accuracy did not improve from 0.84571
#
# Epoch 691: val_accuracy did not improve from 0.84571
#
# Epoch 692: val_accuracy did not improve from 0.84571
#
# Epoch 693: val_accuracy did not improve from 0.84571
#
# Epoch 694: val_accuracy did not improve from 0.84571
#
# Epoch 695: val_accuracy did not improve from 0.84571
#
# Epoch 696: val_accuracy did not improve from 0.84571
#
# Epoch 697: val_accuracy did not improve from 0.84571
#
# Epoch 698: val_accuracy did not improve from 0.84571
#
# Epoch 699: val_accuracy did not improve from 0.84571
#
# Epoch 700: val_accuracy did not improve from 0.84571
#
# Epoch 701: val_accuracy did not improve from 0.84571
#
# Epoch 702: val_accuracy did not improve from 0.84571
#
# Epoch 703: val_accuracy did not improve from 0.84571
#
# Epoch 704: val_accuracy did not improve from 0.84571
#
# Epoch 705: val_accuracy did not improve from 0.84571
#
# Epoch 706: val_accuracy did not improve from 0.84571
#
# Epoch 707: val_accuracy did not improve from 0.84571
#
# Epoch 708: val_accuracy did not improve from 0.84571
#
# Epoch 709: val_accuracy did not improve from 0.84571
#
# Epoch 710: val_accuracy did not improve from 0.84571
#
# Epoch 711: val_accuracy did not improve from 0.84571
#
# Epoch 712: val_accuracy did not improve from 0.84571
#
# Epoch 713: val_accuracy did not improve from 0.84571
#
# Epoch 714: val_accuracy did not improve from 0.84571
#
# Epoch 715: val_accuracy did not improve from 0.84571
#
# Epoch 716: val_accuracy did not improve from 0.84571
#
# Epoch 717: val_accuracy did not improve from 0.84571
#
# Epoch 718: val_accuracy did not improve from 0.84571
#
# Epoch 719: val_accuracy did not improve from 0.84571
#
# Epoch 720: val_accuracy did not improve from 0.84571
#
# Epoch 721: val_accuracy did not improve from 0.84571
#
# Epoch 722: val_accuracy did not improve from 0.84571
#
# Epoch 723: val_accuracy did not improve from 0.84571
#
# Epoch 724: val_accuracy did not improve from 0.84571
#
# Epoch 725: val_accuracy did not improve from 0.84571
#
# Epoch 726: val_accuracy did not improve from 0.84571
#
# Epoch 727: val_accuracy did not improve from 0.84571
#
# Epoch 728: val_accuracy did not improve from 0.84571
#
# Epoch 729: val_accuracy did not improve from 0.84571
#
# Epoch 730: val_accuracy did not improve from 0.84571
#
# Epoch 731: val_accuracy did not improve from 0.84571
#
# Epoch 732: val_accuracy did not improve from 0.84571
#
# Epoch 733: val_accuracy did not improve from 0.84571
#
# Epoch 734: val_accuracy did not improve from 0.84571
#
# Epoch 735: val_accuracy did not improve from 0.84571
#
# Epoch 736: val_accuracy did not improve from 0.84571
#
# Epoch 737: val_accuracy did not improve from 0.84571
#
# Epoch 738: val_accuracy did not improve from 0.84571
#
# Epoch 739: val_accuracy did not improve from 0.84571
#
# Epoch 740: val_accuracy did not improve from 0.84571
#
# Epoch 741: val_accuracy did not improve from 0.84571
#
# Epoch 742: val_accuracy did not improve from 0.84571
#
# Epoch 743: val_accuracy did not improve from 0.84571
#
# Epoch 744: val_accuracy did not improve from 0.84571
#
# Epoch 745: val_accuracy did not improve from 0.84571
#
# Epoch 746: val_accuracy did not improve from 0.84571
#
# Epoch 747: val_accuracy did not improve from 0.84571
#
# Epoch 748: val_accuracy did not improve from 0.84571
#
# Epoch 749: val_accuracy did not improve from 0.84571
#
# Epoch 750: val_accuracy did not improve from 0.84571
#
# Epoch 751: val_accuracy did not improve from 0.84571
#
# Epoch 752: val_accuracy did not improve from 0.84571
#
# Epoch 753: val_accuracy did not improve from 0.84571
#
# Epoch 754: val_accuracy did not improve from 0.84571
#
# Epoch 755: val_accuracy did not improve from 0.84571
#
# Epoch 756: val_accuracy did not improve from 0.84571
#
# Epoch 757: val_accuracy did not improve from 0.84571
#
# Epoch 758: val_accuracy did not improve from 0.84571
#
# Epoch 759: val_accuracy did not improve from 0.84571
#
# Epoch 760: val_accuracy did not improve from 0.84571
#
# Epoch 761: val_accuracy did not improve from 0.84571
#
# Epoch 762: val_accuracy did not improve from 0.84571
#
# Epoch 763: val_accuracy did not improve from 0.84571
#
# Epoch 764: val_accuracy did not improve from 0.84571
#
# Epoch 765: val_accuracy did not improve from 0.84571
#
# Epoch 766: val_accuracy did not improve from 0.84571
#
# Epoch 767: val_accuracy did not improve from 0.84571
#
# Epoch 768: val_accuracy did not improve from 0.84571
#
# Epoch 769: val_accuracy did not improve from 0.84571
#
# Epoch 770: val_accuracy did not improve from 0.84571
#
# Epoch 771: val_accuracy did not improve from 0.84571
#
# Epoch 772: val_accuracy did not improve from 0.84571
#
# Epoch 773: val_accuracy did not improve from 0.84571
#
# Epoch 774: val_accuracy did not improve from 0.84571
#
# Epoch 775: val_accuracy did not improve from 0.84571
#
# Epoch 776: val_accuracy did not improve from 0.84571
#
# Epoch 777: val_accuracy did not improve from 0.84571
#
# Epoch 778: val_accuracy did not improve from 0.84571
#
# Epoch 779: val_accuracy did not improve from 0.84571
#
# Epoch 780: val_accuracy did not improve from 0.84571
#
# Epoch 781: val_accuracy did not improve from 0.84571
#
# Epoch 782: val_accuracy did not improve from 0.84571
#
# Epoch 783: val_accuracy did not improve from 0.84571
#
# Epoch 784: val_accuracy did not improve from 0.84571
#
# Epoch 785: val_accuracy did not improve from 0.84571
#
# Epoch 786: val_accuracy did not improve from 0.84571
#
# Epoch 787: val_accuracy did not improve from 0.84571
#
# Epoch 788: val_accuracy did not improve from 0.84571
#
# Epoch 789: val_accuracy did not improve from 0.84571
#
# Epoch 790: val_accuracy did not improve from 0.84571
#
# Epoch 791: val_accuracy did not improve from 0.84571
#
# Epoch 792: val_accuracy did not improve from 0.84571
#
# Epoch 793: val_accuracy did not improve from 0.84571
#
# Epoch 794: val_accuracy did not improve from 0.84571
#
# Epoch 795: val_accuracy did not improve from 0.84571
#
# Epoch 796: val_accuracy did not improve from 0.84571
#
# Epoch 797: val_accuracy did not improve from 0.84571
#
# Epoch 798: val_accuracy did not improve from 0.84571
#
# Epoch 799: val_accuracy did not improve from 0.84571
#
# Epoch 800: val_accuracy did not improve from 0.84571
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1270 - accuracy: 0.8457
# 2:800 0.845714271068573

# %%
from tensorflow.keras.optimizers import SGD

opt = SGD(lr=0.01, momentum=0.9)

model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(5, input_shape=(5, )))
model.add(tf.keras.layers.Dense(16, activation="relu"))
model.add(tf.keras.layers.Dense(10, activation="relu"))
model.add(tf.keras.layers.Dense(5, activation="relu"))
model.add(tf.keras.layers.Dense(1, activation="sigmoid"))
model.compile(optimizer=opt, metrics='accuracy', loss='mse')

checkpoint = ModelCheckpoint('/content/checkpts_3_200.hdf5', monitor='val_accuracy', verbose=0, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

model.fit(x_train, y_train, batch_size=15, epochs=200, verbose=0, validation_data=(x_test, y_test), callbacks=callbacks_list)
model.load_weights("checkpts_3_200.hdf5")
_, acc = model.evaluate(x_test, y_test)
print('3:200 '+str(acc))

model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(5, input_shape=(5, )))
model.add(tf.keras.layers.Dense(16, activation="relu"))
model.add(tf.keras.layers.Dense(10, activation="relu"))
model.add(tf.keras.layers.Dense(5, activation="relu"))
model.add(tf.keras.layers.Dense(1, activation="sigmoid"))
model.compile(optimizer=opt, metrics='accuracy', loss='mse')

checkpoint = ModelCheckpoint('/content/checkpts_3_400.hdf5', monitor='val_accuracy', verbose=0, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

model.fit(x_train, y_train, batch_size=15, epochs=400, verbose=0, validation_data=(x_test, y_test), callbacks=callbacks_list)
model.load_weights("checkpts_3_400.hdf5")
_, acc = model.evaluate(x_test, y_test)
print('3:400 '+str(acc))

model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(5, input_shape=(5, )))
model.add(tf.keras.layers.Dense(16, activation="relu"))
model.add(tf.keras.layers.Dense(10, activation="relu"))
model.add(tf.keras.layers.Dense(5, activation="relu"))
model.add(tf.keras.layers.Dense(1, activation="sigmoid"))
model.compile(optimizer=opt, metrics='accuracy', loss='mse')

checkpoint = ModelCheckpoint('/content/checkpts_3_800.hdf5', monitor='val_accuracy', verbose=0, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

model.fit(x_train, y_train, batch_size=15, epochs=800, verbose=0, validation_data=(x_test, y_test), callbacks=callbacks_list)
model.load_weights("checkpts_3_800.hdf5")
_, acc = model.evaluate(x_test, y_test)
print('3:800 '+str(acc))
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1312 - accuracy: 0.8400
# 3:200 0.8399999737739563
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1295 - accuracy: 0.8514
# 3:400 0.8514285683631897
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1254 - accuracy: 0.8571
# 3:800 0.8571428656578064
